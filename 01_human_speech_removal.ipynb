# %%
import numpy as np
import pandas as pd
import os
import torch
import pickle
from tqdm.notebook import tqdm

# %%
# --- Define Kaggle Paths ---
# Verify the competition slug is correct in the input path
COMPETITION_SLUG = 'birdclef-2025'
BASE_INPUT_PATH = os.path.join('/kaggle/input', COMPETITION_SLUG)
TRAIN_CSV_PATH = os.path.join(BASE_INPUT_PATH, 'train.csv')
TRAIN_AUDIO_DIR = os.path.join(BASE_INPUT_PATH, 'train_audio/')

# Kaggle's writable directory for output
OUTPUT_DIR = '/kaggle/working/'
OUTPUT_PKL_PATH = os.path.join(OUTPUT_DIR, 'train_audio_speech_timestamps.pkl')
# --- End Path Definitions ---

print(f"Train CSV Path: {TRAIN_CSV_PATH}")
print(f"Train Audio Directory: {TRAIN_AUDIO_DIR}")
print(f"Output Pickle Path: {OUTPUT_PKL_PATH}")

# Check if input paths exist (sanity check)
print(f"\nTrain CSV exists: {os.path.exists(TRAIN_CSV_PATH)}")
print(f"Train Audio directory exists: {os.path.exists(TRAIN_AUDIO_DIR)}")

# Ensure the output directory exists (it should by default)
os.makedirs(OUTPUT_DIR, exist_ok=True)
# Out:
# Train CSV Path: /kaggle/input/birdclef-2025/train.csv
# Train Audio Directory: /kaggle/input/birdclef-2025/train_audio/
# Output Pickle Path: /kaggle/working/train_audio_speech_timestamps.pkl
#
# Train CSV exists: True
# Train Audio directory exists: True

# %%
# --- Device Setup ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if device.type == 'cuda':
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

# --- Load Silero VAD Model ---
model = None # Initialize
utils = None # Initialize
print("Loading Silero VAD model (requires internet for first download)...")
# Use force_reload=False after the first download
model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad',
                              model='silero_vad',
                              force_reload=False,
                              onnx=False, # Use PyTorch version
                              trust_repo=True) # Add if required by torch version
(get_speech_timestamps, _, read_audio, _, _) = utils

model.to(device) 
print("Silero VAD model loaded successfully.")
# Out:
# Using device: cpu
# Loading Silero VAD model (requires internet for first download)...
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip
# Silero VAD model loaded successfully.

# %%
# --- Load Train Metadata ---
train_df = None # Initialize
if os.path.exists(TRAIN_CSV_PATH):
    try:
        train_df = pd.read_csv(TRAIN_CSV_PATH)
        print(f"Loaded train metadata with {len(train_df)} entries.")
        # Optional: Use a subset for quick testing
        # train_df = train_df.head(100).copy()
        # print(f"Using subset of {len(train_df)} entries for testing.")
    except Exception as e:
        print(f"Error loading {TRAIN_CSV_PATH}: {e}")
else:
    print(f"ERROR: Train CSV not found at {TRAIN_CSV_PATH}. Cannot proceed.")
# Out:
# Loaded train metadata with 28564 entries.

# %%
train_df_deduplicated = None # Initialize variable for the deduplicated DataFrame

if train_df is not None:
    print("\n--- Checking for Metadata Duplicates ---")
    original_rows = len(train_df)
    print(f"Original number of rows in train_df: {original_rows}")

    # Define columns to identify potential duplicate recordings
    # Common choices, adjust if you have better criteria
    duplicate_check_cols = ['primary_label', 'latitude', 'longitude', 'author']
    print(f"Checking for duplicates based on columns: {duplicate_check_cols}")

    # Verify that all specified columns actually exist in the DataFrame
    if all(col in train_df.columns for col in duplicate_check_cols):

        # Create a temporary copy for checking duplicates, handling potential NaNs
        temp_df_for_dup_check = train_df[duplicate_check_cols].copy()
        for col in duplicate_check_cols:
            if temp_df_for_dup_check[col].isnull().any():
                # Fill NaNs appropriately based on column type to allow duplication check
                if pd.api.types.is_numeric_dtype(temp_df_for_dup_check[col]):
                    temp_df_for_dup_check[col] = temp_df_for_dup_check[col].fillna(-9999) # Or another suitable numeric placeholder
                else:
                    temp_df_for_dup_check[col] = temp_df_for_dup_check[col].fillna('__MISSING__') # String placeholder

        duplicates_mask = temp_df_for_dup_check.duplicated(keep='first')
        num_duplicates = duplicates_mask.sum()
        print(f"Number of potential duplicate rows identified: {num_duplicates}")

        if num_duplicates > 0:
            train_df_deduplicated = train_df[~duplicates_mask].copy()
            print(f"Number of rows after removing duplicates: {len(train_df_deduplicated)}")
        else:
            print("No metadata duplicates found based on selected columns.")
            train_df_deduplicated = train_df.copy() # No duplicates found, use the original df

    else:
        missing_cols = [col for col in duplicate_check_cols if col not in train_df.columns]
        print(f"Warning: Cannot check duplicates. Columns not found: {missing_cols}")
        print("Proceeding without deduplication.")
        train_df_deduplicated = train_df.copy() # Use original if columns are missing

else:
    print("Skipping duplicate check: train_df was not loaded.")
# Out:
# --- Checking for Metadata Duplicates ---
# Original number of rows in train_df: 28564
# Checking for duplicates based on columns: ['primary_label', 'latitude', 'longitude', 'author']
# Number of potential duplicate rows identified: 7119
# Number of rows after removing duplicates: 21445

# %%
train_df = train_df_deduplicated

# %%
TAXON_CSV_PATH = os.path.join(BASE_INPUT_PATH, 'taxonomy.csv')
taxonomy_df = pd.read_csv(TAXON_CSV_PATH)

# %%
bird_audio_df = pd.DataFrame()

if taxonomy_df is not None and train_df is not None:
    if 'primary_label' in taxonomy_df.columns and 'primary_label' in train_df.columns:
        # use a left merge to keep all rows from train_df
        merged_df = pd.merge(train_df, taxonomy_df[['primary_label', 'class_name']], on='primary_label', how='left')

        # Filter for rows where class_name is 'Aves'
        bird_audio_df = merged_df[merged_df['class_name'] == 'Aves'].copy()
        
        num_total_files = len(merged_df)
        num_bird_files = len(bird_audio_df)
        print(f"Filtered for bird species ('Aves'): {num_bird_files} files out of {num_total_files} will be processed for speech.")

        if num_bird_files == 0 and num_total_files > 0:
            print("Warning: No bird species files found after filtering. Check 'Aves' spelling and taxonomy data.")
# Out:
# Filtered for bird species ('Aves'): 20761 files out of 21445 will be processed for speech.

# %% [markdown]
# ## Class distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# --- Select DataFrame to Analyze ---
# Preferably use the deduplicated dataframe if it exists and is not None
df_to_analyze = None
df_name = ""
if 'train_df_deduplicated' in locals() and train_df_deduplicated is not None:
    df_to_analyze = train_df_deduplicated
    df_name = "train_df_deduplicated"
    print("Analyzing deduplicated data.")
elif 'train_df' in locals() and train_df is not None:
    # Fallback to original if deduplicated version doesn't exist/wasn't run
    df_to_analyze = train_df
    df_name = "train_df"
    print("Analyzing original train_df (deduplicated version not found/available).")
else:
     print("Cannot analyze class imbalance: DataFrame not loaded.")

# --- Perform Analysis if DataFrame is available ---
if df_to_analyze is not None:
    # Check if the primary_label column exists
    if 'primary_label' in df_to_analyze.columns:
        print(f"\n--- Analyzing Class Distribution in {df_name} ---")

        # Get the counts for each unique value in 'primary_label'
        # This series will have the label as index and count as value, sorted descending
        class_counts = df_to_analyze['primary_label'].value_counts()

        # --- Print Summary Information ---
        print(f"Total number of unique classes (species): {len(class_counts)}")
        print(f"Total number of samples analyzed: {df_to_analyze.shape[0]}")

        print("\n--- Top 10 Most Frequent Classes ---")
        print(class_counts.head(10))

        print("\n--- Bottom 10 Least Frequent Classes ---")
        print(class_counts.tail(10))

        print("\n--- Distribution Statistics (Counts per class) ---")
        # Provides min, max, mean, std, quartiles for the counts
        print(class_counts.describe())

        # --- Optional: Visualize the Distribution ---
        print("\n--- Plotting Class Distribution (Top 50) ---")
        try:
            plt.figure(figsize=(15, 8)) # Adjust figure size as needed

            # Determine number of classes to plot for clarity
            N_TO_PLOT = 50
            if len(class_counts) > N_TO_PLOT:
                plot_data = class_counts.head(N_TO_PLOT)
                title = f'Frequency of Top {N_TO_PLOT} Primary Labels in {df_name}'
            else:
                plot_data = class_counts
                title = f'Frequency of All Primary Labels in {df_name}'

            # Create bar plot
            sns.barplot(x=plot_data.index, y=plot_data.values, palette="viridis") # Added palette
            plt.title(title, fontsize=16)
            plt.ylabel('Number of Recordings', fontsize=12)
            plt.xlabel('Primary Label (Species Code)', fontsize=12)
            plt.xticks(rotation=90, fontsize=8) # Rotate labels for better readability
            plt.tight_layout() # Adjust layout
            plt.show()

        except ImportError:
            print("\nInstall matplotlib and seaborn (`pip install matplotlib seaborn`) to generate plot.")
        except Exception as e:
            print(f"\nError generating plot: {e}")

    else: # primary_label column missing
        print(f"Cannot analyze class imbalance: 'primary_label' column not found in {df_name}.")
# Out:
# Analyzing deduplicated data.
#
# --- Analyzing Class Distribution in train_df_deduplicated ---
# Total number of unique classes (species): 206
# Total number of samples analyzed: 21445
#
# --- Top 10 Most Frequent Classes ---
# primary_label
# grekis     799
# compau     631
# trokin     596
# roahaw     551
# whtdov     467
# banana     450
# soulap1    409
# bobfly1    402
# socfly1    394
# yeofly1    387
# Name: count, dtype: int64
#
# --- Bottom 10 Least Frequent Classes ---
# primary_label
# 1462711    2
# 868458     1
# 523060     1
# 1564122    1
# 715170     1
# 714022     1
# 528041     1
# 66016      1
# 548639     1
# 1139490    1
# Name: count, dtype: int64
#
# --- Distribution Statistics (Counts per class) ---
# count    206.000000
# mean     104.101942
# std      130.614474
# min        1.000000
# 25%       13.250000
# 50%       60.000000
# 75%      139.000000
# max      799.000000
# Name: count, dtype: float64
#
# --- Plotting Class Distribution (Top 50) ---

# %% [markdown]
# # Multiprocessing to remove human speech

# %%
import multiprocessing
num_processes = multiprocessing.cpu_count()
print(f"Using {num_processes} processes.")
# Out:
# Using 4 processes.

# %%
# --- Define VAD Constants & Function ---
VAD_SAMPLING_RATE = 16000 # Silero VAD expects 8k or 16k
VAD_THRESHOLD = 0.7 # Speech confidence threshold

def extract_speech_timestamps(audio_path, model, read_audio_func, get_timestamps_func, device):
    """
    Loads audio, runs Silero VAD, returns speech timestamps in seconds.
    Returns None if error or no speech detected.
    """
    if not model or not read_audio_func or not get_timestamps_func:
        return None # Model or utils not loaded
    try:
        # read_audio loads and resamples to VAD_SAMPLING_RATE
        wav = read_audio_func(audio_path, sampling_rate=VAD_SAMPLING_RATE)
        wav_tensor = wav.to(device) # Move audio tensor to device

        # Get timestamps
        speech_timestamps = get_timestamps_func(wav_tensor, model,
                                                sampling_rate=VAD_SAMPLING_RATE,
                                                threshold=VAD_THRESHOLD,
                                                return_seconds=True)

        # Return list if not empty, else None
        return speech_timestamps if speech_timestamps else None
    except Exception as e:
        # Optional: Log errors if needed for debugging specific files
        # print(f"Error processing file {os.path.basename(audio_path)}: {e}")
        return None # Indicate failure
print("Timestamp extraction function defined.")
# Out:
# Timestamp extraction function defined.

# %%
def process_single_file(args):
    filename, audio_dir, device_spec, model_repo, model_name_in_repo = args

    local_model = None
    local_read_audio = None
    local_get_speech_timestamps = None

    try:
        # 1. Load model and utils LOCALLY in this worker process
        #    Replace with your actual torch.hub.load arguments
        temp_model, temp_utils = torch.hub.load(
            repo_or_dir=model_repo, # e.g., 'snakers4/silero-vad'
            model=model_name_in_repo,    # e.g., 'silero_vad'
            trust_repo=True,
            force_reload=False # Set to True for first download or updates
        )
        (local_get_speech_timestamps, _, local_read_audio, _, _) = temp_utils
        local_model = temp_model
        local_model.to(device_spec) # Move the model to the specified device

    except Exception as e:
        print(f"Error loading VAD model in worker for {filename}: {e}")
        return filename, None # Critical error, cannot process

    # Construct the full path to the audio file
    full_audio_path = os.path.join(audio_dir, filename)

    # 2. Call your existing extract_speech_timestamps function
    #    It will use the locally loaded model/utils and your VAD_THRESHOLD
    timestamps = extract_speech_timestamps(
        full_audio_path,
        local_model,
        local_read_audio,
        local_get_speech_timestamps,
        device_spec # The device the model is on, and data might need to be moved to.
    )
    
    return filename, timestamps

# %%
# --- Ensure your model and utils are loaded and device is set ---
# The model loaded here in the main process won't be passed to workers anymore.
# It can be used for other tasks or removed if only parallel processing is done.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Example for Silero VAD:
MODEL_REPO_OR_DIR = 'snakers4/silero-vad'
MODEL_NAME_IN_REPO = 'silero_vad'
# For other models, you'll need to find their specific torch.hub.load arguments.

# --- Prepare arguments for parallel processing ---
# Only process files that are confirmed to be bird audio
df_to_process = bird_audio_df # As in your notebook
filenames_to_process = df_to_process['filename'].tolist()

# The 'device' here will be passed to each worker to tell it where to load its model.
# If using GPU, ensure each process doesn't overload the GPU memory.
# Using torch.device('cpu') for workers can be safer if GPU memory is a concern.
device_for_worker_processes = device # Or explicitly torch.device('cpu')

# Update file_args: model and utils-derived functions are removed,
# model loading parameters are added.
file_args = [
    (fn, TRAIN_AUDIO_DIR, device_for_worker_processes, MODEL_REPO_OR_DIR, MODEL_NAME_IN_REPO)
    for fn in filenames_to_process
]

num_processes = multiprocessing.cpu_count()
all_speech_timestamps_parallel = {}

# --- Use multiprocessing.Pool ---
# Ensure process_single_file is defined above this point.
print(f"Starting speech detection for {len(filenames_to_process)} audio files using parallel processing...")

# It's good practice to set the start method for multiprocessing, especially on macOS or Windows
multiprocessing.set_start_method('spawn', force=True) # 'spawn' is often more robust

with multiprocessing.Pool(processes=num_processes) as pool:
    results = list(tqdm(pool.imap(process_single_file, file_args), total=len(file_args), desc="Detecting Speech (Parallel)"))

for filename, timestamps in results:
    if timestamps: # Check if timestamps is not None (in case of error during processing)
        all_speech_timestamps_parallel[filename] = timestamps

print(f"\nFinished parallel processing.")
print(f"Detected speech segments in {len(all_speech_timestamps_parallel)} out of {len(filenames_to_process)} files.")
try:
    with open(OUTPUT_PKL_PATH, 'wb') as f: # Or a new path for parallel results
        pickle.dump(all_speech_timestamps_parallel, f)
    print(f"Successfully saved speech timestamps dictionary to {OUTPUT_PKL_PATH}")
except Exception as e:
    print(f"Error saving results to pickle file: {e}")
# Out:
# Starting speech detection for 20761 audio files using parallel processing...
# Detecting Speech (Parallel):   0%|          | 0/20761 [00:00<?, ?it/s]
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# ...
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master
# Using cache found in /root/.cache/torch/hub/snakers4_silero-vad_master

# %%
# --- Process Audio Files and Save Timestamps ---
# N_FILES_TO_TEST = 200

all_speech_timestamps = {} 
print(f"Results will be saved to: {OUTPUT_PKL_PATH}")
# test_output_pkl_path = os.path.join(OUTPUT_DIR, f'train_audio_speech_timestamps_TEST_{N_FILES_TO_TEST}.pkl')
# print(f"Test results will be saved to: {test_output_pkl_path}")

print(f"Starting speech detection for {len(bird_audio_df)} audio files...")
# df_to_process = bird_audio_df.head(N_FILES_TO_TEST).copy()
# print(f"Processing a SUBSET of {len(df_to_process)} bird audio files.")
df_to_process = bird_audio_df

# Iterate through the DataFrame with a progress bar
for index, row in tqdm(df_to_process.iterrows(), total=df_to_process.shape[0], desc="Detecting Speech"):
    filename = row['filename']

    audio_file_path = os.path.join(TRAIN_AUDIO_DIR, filename)

    if os.path.exists(audio_file_path):
        
        timestamps = extract_speech_timestamps(audio_file_path, model, read_audio, get_speech_timestamps, device)
        # If timestamps were found (list is not empty), store them
        if timestamps:
            all_speech_timestamps[filename] = timestamps

print(f"\nFinished processing.")
print(f"Detected speech segments in {len(all_speech_timestamps)} out of {len(df_to_process)} files.")

try:
    with open(OUTPUT_PKL_PATH, 'wb') as f:
        pickle.dump(all_speech_timestamps, f)
    print(f"Successfully saved speech timestamps dictionary to {OUTPUT_PKL_PATH}")
except Exception as e:
    print(f"Error saving results to pickle file: {e}")
# Out:
# Results will be saved to: /kaggle/working/train_audio_speech_timestamps.pkl
# Starting speech detection for 20761 audio files...
# Detecting Speech:   0%|          | 0/20761 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31/1499994926.py in <cell line: 0>()
#      20     if os.path.exists(audio_file_path):
#      21
# ---> 22         timestamps = extract_speech_timestamps(audio_file_path, model, read_audio, get_speech_timestamps, device)
#      23         # If timestamps were found (list is not empty), store them
#      24         if timestamps:
#
# /tmp/ipykernel_31/3726529986.py in extract_speech_timestamps(audio_path, model, read_audio_func, get_timestamps_func, device)
#      16
#      17         # Get timestamps
# ---> 18         speech_timestamps = get_timestamps_func(wav_tensor, model,
#      19                                                 sampling_rate=VAD_SAMPLING_RATE,
#      20                                                 threshold=VAD_THRESHOLD,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ~/.cache/torch/hub/snakers4_silero-vad_master/src/silero_vad/utils_vad.py in get_speech_timestamps(audio, model, threshold, sampling_rate, min_speech_duration_ms, max_speech_duration_s, min_silence_duration_ms, speech_pad_ms, return_seconds, time_resolution, visualize_probs, progress_tracking_callback, neg_threshold, window_size_samples)
#     298         if len(chunk) < window_size_samples:
#     299             chunk = torch.nn.functional.pad(chunk, (0, int(window_size_samples - len(chunk))))
# --> 300         speech_prob = model(chunk, sampling_rate).item()
#     301         speech_probs.append(speech_prob)
#     302         # caculate progress and seng it to callback function
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# KeyboardInterrupt:

# %%
pkl_file_path = "/kaggle/working/train_audio_speech_timestamps.pkl"
print(f"Loading data from: {pkl_file_path}")
with open(pkl_file_path, 'rb') as f:
    loaded_speech_data = pickle.load(f)
# Out:
# Loading data from: /kaggle/working/train_audio_speech_timestamps.pkl

# %%
len(loaded_speech_data)
# Out:
# 1308

# %%
loaded_speech_data
# Out:
# {'amakin1/XC550401.ogg': [{'start': 4.6, 'end': 6.4}],
#  'amakin1/XC654346.ogg': [{'start': 4.1, 'end': 6.1},
#   {'start': 6.3, 'end': 6.7}],
#  'amekes/XC238264.ogg': [{'start': 0.6, 'end': 1.1},
#   {'start': 9.3, 'end': 10.5}],
#  'amekes/XC517945.ogg': [{'start': 45.0, 'end': 45.6},
#   {'start': 46.6, 'end': 47.7},
#   {'start': 50.3, 'end': 51.7},
#   {'start': 53.9, 'end': 55.0},
#   {'start': 62.2, 'end': 62.9},
#   {'start': 64.7, 'end': 66.4},
#   {'start': 66.7, 'end': 67.6},
#   {'start': 68.5, 'end': 69.9},
#   {'start': 70.4, 'end': 70.9},
#   {'start': 72.9, 'end': 74.2},
#   {'start': 80.5, 'end': 84.1}],
#  'amekes/XC59480.ogg': [{'start': 5.3, 'end': 6.2},
#   {'start': 8.1, 'end': 8.6}],
#  'amekes/XC786360.ogg': [{'start': 6.3, 'end': 7.6},
#   {'start': 8.8, 'end': 10.6}],
#  'amekes/iNat1150468.ogg': [{'start': 0.5, 'end': 0.8},
#   {'start': 7.8, 'end': 8.6}],
#  'amekes/iNat1237278.ogg': [{'start': 2.9, 'end': 3.5}],
#  'amekes/iNat1289544.ogg': [{'start': 38.4, 'end': 39.7},
#   {'start': 43.1, 'end': 44.0},
#   {'start': 44.7, 'end': 45.3},
#   {'start': 45.8, 'end': 46.8},
#   {'start': 47.3, 'end': 48.3},
#   {'start': 48.5, 'end': 48.9},
#   {'start': 49.6, 'end': 52.8},
#   {'start': 53.0, 'end': 54.9},
#   {'start': 55.7, 'end': 56.1},
#   {'start': 56.3, 'end': 58.3},
#   {'start': 58.8, 'end': 60.6},
#   {'start': 61.5, 'end': 62.5},
#   {'start': 62.8, 'end': 63.6},
#   {'start': 66.1, 'end': 68.6},
#   {'start': 69.3, 'end': 69.9},
#   {'start': 70.6, 'end': 74.0},
#   {'start': 74.6, 'end': 76.1},
#   {'start': 80.3, 'end': 80.7},
#   {'start': 80.9, 'end': 84.4},
#   {'start': 84.7, 'end': 85.5},
#   {'start': 85.8, 'end': 86.8},
#   {'start': 87.6, 'end': 89.4},
#   {'start': 89.6, 'end': 90.1},
#   {'start': 90.6, 'end': 96.5},
#   {'start': 97.1, 'end': 99.6},
#   {'start': 100.3, 'end': 101.1},
#   {'start': 101.8, 'end': 102.2}],
#  'amekes/iNat351906.ogg': [{'start': 8.3, 'end': 9.0}],
#  'amekes/iNat522503.ogg': [{'start': 12.6, 'end': 13.2},
#   {'start': 13.7, 'end': 14.0},
#   {'start': 14.8, 'end': 15.466}],
#  'amekes/iNat740074.ogg': [{'start': 0.3, 'end': 0.9},
#   {'start': 1.1, 'end': 6.1},
#   {'start': 7.1, 'end': 8.8}],
#  'amekes/iNat863228.ogg': [{'start': 3.7, 'end': 4.2},
#   {'start': 4.4, 'end': 5.1},
#   {'start': 8.2, 'end': 9.5},
#   {'start': 11.2, 'end': 12.6},
#   {'start': 13.0, 'end': 15.0},
#   {'start': 15.3, 'end': 15.966}],
#  'amekes/iNat979407.ogg': [{'start': 4.9, 'end': 5.382}],
#  'ampkin1/XC119450.ogg': [{'start': 2.6, 'end': 3.4}],
#  'ampkin1/XC181622.ogg': [{'start': 4.0, 'end': 4.3}],
#  'ampkin1/XC260564.ogg': [{'start': 3.6, 'end': 4.2}],
#  'ampkin1/XC694924.ogg': [{'start': 41.6, 'end': 43.5},
#   {'start': 44.3, 'end': 44.7},
#   {'start': 45.0, 'end': 45.4},
#   {'start': 45.6, 'end': 46.5},
#   {'start': 47.1, 'end': 47.7},
#   {'start': 50.3, 'end': 51.1}],
#  'anhing/XC108819.ogg': [{'start': 1.5, 'end': 1.9}],
#  'anhing/XC530669.ogg': [{'start': 3.4, 'end': 4.1}],
#  'anhing/iNat952211.ogg': [{'start': 4.5, 'end': 5.9}],
#  'babwar/XC138050.ogg': [{'start': 0.6, 'end': 1.8},
#   {'start': 2.3, 'end': 2.8}],
#  'babwar/XC177039.ogg': [{'start': 0.4, 'end': 2.0}],
#  'babwar/XC67171.ogg': [{'start': 1.4, 'end': 2.0}],
#  'babwar/iNat1157260.ogg': [{'start': 0.3, 'end': 6.4}],
#  'bafibi1/XC422113.ogg': [{'start': 1.7, 'end': 3.0}],
#  'bafibi1/XC946174.ogg': [{'start': 0.9, 'end': 3.1}],
#  'banana/XC113782.ogg': [{'start': 0.4, 'end': 1.3},
#   {'start': 4.5, 'end': 5.8}],
#  'banana/XC128032.ogg': [{'start': 2.7, 'end': 4.5},
#   {'start': 6.8, 'end': 11.2},
#   {'start': 13.2, 'end': 18.2},
#   {'start': 21.5, 'end': 24.4},
#   {'start': 28.2, 'end': 30.6},
#   {'start': 33.8, 'end': 36.0},
#   {'start': 39.4, 'end': 39.9},
#   {'start': 40.7, 'end': 42.4},
#   {'start': 45.7, 'end': 47.3},
#   {'start': 47.9, 'end': 48.2},
#   {'start': 48.5, 'end': 49.0},
#   {'start': 53.2, 'end': 54.2},
#   {'start': 63.0, 'end': 63.9},
#   {'start': 67.3, 'end': 68.1},
#   {'start': 68.5, 'end': 69.2},
#   {'start': 72.8, 'end': 74.3},
#   {'start': 79.1, 'end': 79.5}],
#  'banana/XC140241.ogg': [{'start': 2.4, 'end': 3.2}],
#  'banana/XC146976.ogg': [{'start': 1.3, 'end': 1.7}],
#  'banana/XC149227.ogg': [{'start': 2.2, 'end': 2.9}],
#  'banana/XC151364.ogg': [{'start': 1.2, 'end': 1.7},
#   {'start': 1.9, 'end': 2.6}],
#  'banana/XC166399.ogg': [{'start': 2.6, 'end': 3.2}],
#  'banana/XC177791.ogg': [{'start': 3.4, 'end': 4.0}],
#  'banana/XC190593.ogg': [{'start': 3.6, 'end': 5.0},
#   {'start': 11.0, 'end': 11.6},
#   {'start': 12.6, 'end': 13.2},
#   {'start': 16.7, 'end': 17.4},
#   {'start': 17.7, 'end': 18.0},
#   {'start': 18.6, 'end': 18.9},
#   {'start': 22.6, 'end': 23.1},
#   {'start': 24.2, 'end': 24.9},
#   {'start': 29.3, 'end': 29.8},
#   {'start': 30.1, 'end': 30.6},
#   {'start': 30.9, 'end': 31.2},
#   {'start': 34.1, 'end': 34.6},
#   {'start': 39.2, 'end': 39.7},
#   {'start': 40.0, 'end': 40.5},
#   {'start': 43.8, 'end': 44.2},
#   {'start': 48.2, 'end': 49.0},
#   {'start': 49.3, 'end': 49.8},
#   {'start': 55.0, 'end': 55.4},
#   {'start': 56.2, 'end': 56.8},
#   {'start': 60.7, 'end': 61.1},
#   {'start': 61.4, 'end': 61.9},
#   {'start': 62.3, 'end': 62.6},
#   {'start': 74.8, 'end': 75.3}],
#  'banana/XC1926.ogg': [{'start': 0.8, 'end': 1.3},
#   {'start': 14.3, 'end': 14.7}],
#  'banana/XC199048.ogg': [{'start': 9.2, 'end': 10.0}],
#  'banana/XC211811.ogg': [{'start': 1.5, 'end': 2.7},
#   {'start': 5.5, 'end': 8.1},
#   {'start': 10.8, 'end': 11.2},
#   {'start': 11.5, 'end': 12.7},
#   {'start': 15.0, 'end': 16.9},
#   {'start': 17.0, 'end': 17.3},
#   {'start': 19.7, 'end': 21.9},
#   {'start': 24.4, 'end': 26.8},
#   {'start': 30.2, 'end': 31.5},
#   {'start': 34.9, 'end': 36.5},
#   {'start': 36.6, 'end': 36.9},
#   {'start': 39.5, 'end': 41.4}],
#  'banana/XC215659.ogg': [{'start': 23.1, 'end': 24.1},
#   {'start': 25.5, 'end': 26.6},
#   {'start': 26.8, 'end': 27.5},
#   {'start': 28.4, 'end': 30.9}],
#  'banana/XC275598.ogg': [{'start': 7.0, 'end': 8.2},
#   {'start': 12.1, 'end': 13.0}],
#  'banana/XC283825.ogg': [{'start': 2.3, 'end': 4.4},
#   {'start': 11.3, 'end': 12.2},
#   {'start': 41.8, 'end': 42.3},
#   {'start': 43.0, 'end': 43.4}],
#  'banana/XC297013.ogg': [{'start': 2.1, 'end': 2.7},
#   {'start': 6.4, 'end': 7.2},
#   {'start': 11.4, 'end': 12.3},
#   {'start': 15.6, 'end': 16.6},
#   {'start': 21.3, 'end': 22.1}],
#  'banana/XC303796.ogg': [{'start': 1.8, 'end': 2.3}],
#  'banana/XC336666.ogg': [{'start': 0.2, 'end': 0.5},
#   {'start': 8.5, 'end': 9.0},
#   {'start': 29.5, 'end': 30.0},
#   {'start': 43.0, 'end': 43.5}],
#  'banana/XC351849.ogg': [{'start': 1.3, 'end': 2.3},
#   {'start': 22.8, 'end': 23.2},
#   {'start': 31.4, 'end': 32.1},
#   {'start': 39.4, 'end': 40.1},
#   {'start': 70.6, 'end': 71.3},
#   {'start': 108.3, 'end': 109.1},
#   {'start': 122.3, 'end': 123.1},
#   {'start': 131.7, 'end': 132.3},
#   {'start': 138.5, 'end': 138.8},
#   {'start': 152.2, 'end': 153.2},
#   {'start': 157.4, 'end': 158.6},
#   {'start': 168.4, 'end': 168.7},
#   {'start': 173.6, 'end': 174.3},
#   {'start': 179.0, 'end': 180.2},
#   {'start': 186.4, 'end': 187.8}],
#  'banana/XC355307.ogg': [{'start': 6.0, 'end': 6.9},
#   {'start': 16.1, 'end': 16.6}],
#  'banana/XC377218.ogg': [{'start': 5.4, 'end': 6.4}],
#  'banana/XC384662.ogg': [{'start': 0.2, 'end': 0.8},
#   {'start': 1.4, 'end': 1.9},
#   {'start': 8.4, 'end': 8.9},
#   {'start': 13.2, 'end': 13.6}],
#  'banana/XC388560.ogg': [{'start': 0.1, 'end': 0.5}],
#  'banana/XC397320.ogg': [{'start': 3.8, 'end': 4.9},
#   {'start': 15.3, 'end': 15.6},
#   {'start': 18.8, 'end': 19.9},
#   {'start': 20.1, 'end': 20.7}],
#  'banana/XC397480.ogg': [{'start': 7.1, 'end': 7.5}],
#  'banana/XC403852.ogg': [{'start': 55.5, 'end': 56.1},
#   {'start': 56.6, 'end': 57.1},
#   {'start': 57.5, 'end': 59.0},
#   {'start': 59.7, 'end': 60.1},
#   {'start': 60.3, 'end': 60.7},
#   {'start': 60.9, 'end': 61.2},
#   {'start': 62.6, 'end': 63.0}],
#  'banana/XC416125.ogg': [{'start': 2.2, 'end': 2.8},
#   {'start': 12.3, 'end': 13.5}],
#  'banana/XC437586.ogg': [{'start': 0.3, 'end': 1.3},
#   {'start': 1.9, 'end': 2.6},
#   {'start': 7.0, 'end': 10.8}],
#  'banana/XC444909.ogg': [{'start': 5.3, 'end': 6.3},
#   {'start': 17.0, 'end': 18.0},
#   {'start': 18.5, 'end': 18.9}],
#  'banana/XC467099.ogg': [{'start': 0.7, 'end': 1.9}],
#  'banana/XC491921.ogg': [{'start': 3.7, 'end': 4.5}],
#  'banana/XC499856.ogg': [{'start': 2.7, 'end': 3.2},
#   {'start': 7.2, 'end': 7.5},
#   {'start': 7.7, 'end': 8.1},
#   {'start': 10.6, 'end': 11.0},
#   {'start': 11.7, 'end': 12.2},
#   {'start': 13.6, 'end': 14.8},
#   {'start': 15.5, 'end': 15.9},
#   {'start': 16.7, 'end': 17.0}],
#  'banana/XC519180.ogg': [{'start': 35.8, 'end': 36.3},
#   {'start': 37.4, 'end': 38.4}],
#  'banana/XC520818.ogg': [{'start': 3.1, 'end': 5.7}],
#  'banana/XC520821.ogg': [{'start': 34.2, 'end': 34.7},
#   {'start': 34.9, 'end': 35.3}],
#  'banana/XC523829.ogg': [{'start': 2.7, 'end': 3.3},
#   {'start': 9.1, 'end': 9.5},
#   {'start': 42.0, 'end': 44.4}],
#  'banana/XC523830.ogg': [{'start': 84.8, 'end': 85.6},
#   {'start': 86.1, 'end': 86.6},
#   {'start': 88.8, 'end': 91.3}],
#  'banana/XC523831.ogg': [{'start': 48.6, 'end': 50.6}],
#  'banana/XC523837.ogg': [{'start': 39.8, 'end': 42.2}],
#  'banana/XC524991.ogg': [{'start': 53.4, 'end': 55.7}],
#  'banana/XC529499.ogg': [{'start': 21.9, 'end': 22.2},
#   {'start': 22.3, 'end': 22.7},
#   {'start': 26.4, 'end': 26.9},
#   {'start': 27.4, 'end': 27.8}],
#  'banana/XC583784.ogg': [{'start': 10.0, 'end': 10.3}],
#  'banana/XC589608.ogg': [{'start': 2.2, 'end': 4.2},
#   {'start': 24.3, 'end': 25.3},
#   {'start': 29.0, 'end': 29.4},
#   {'start': 35.5, 'end': 36.4},
#   {'start': 36.6, 'end': 37.0}],
#  'banana/XC590531.ogg': [{'start': 4.1, 'end': 4.4}],
#  'banana/XC616607.ogg': [{'start': 9.0, 'end': 9.5},
#   {'start': 10.8, 'end': 11.2},
#   {'start': 15.1, 'end': 15.5},
#   {'start': 20.7, 'end': 21.7}],
#  'banana/XC643168.ogg': [{'start': 2.0, 'end': 2.3},
#   {'start': 2.5, 'end': 3.5},
#   {'start': 12.4, 'end': 12.9},
#   {'start': 17.5, 'end': 18.2},
#   {'start': 28.6, 'end': 28.9}],
#  'banana/XC649625.ogg': [{'start': 7.2, 'end': 7.5}],
#  'banana/XC6991.ogg': [{'start': 1.2, 'end': 1.6},
#   {'start': 1.7, 'end': 3.0},
#   {'start': 12.5, 'end': 13.7}],
#  'banana/XC706367.ogg': [{'start': 1.9, 'end': 2.2},
#   {'start': 5.7, 'end': 7.4}],
#  'banana/XC70807.ogg': [{'start': 3.3, 'end': 3.9},
#   {'start': 4.2, 'end': 4.6}],
#  'banana/XC737964.ogg': [{'start': 50.5, 'end': 51.6}],
#  'banana/XC757620.ogg': [{'start': 6.7, 'end': 7.5},
#   {'start': 9.4, 'end': 10.8},
#   {'start': 10.9, 'end': 12.7},
#   {'start': 13.0, 'end': 15.3},
#   {'start': 22.5, 'end': 23.7},
#   {'start': 23.9, 'end': 24.7},
#   {'start': 25.4, 'end': 26.3}],
#  'banana/XC771681.ogg': [{'start': 2.4, 'end': 2.8}],
#  'banana/XC782564.ogg': [{'start': 2.4, 'end': 2.7},
#   {'start': 2.8, 'end': 3.2},
#   {'start': 5.9, 'end': 7.6},
#   {'start': 10.0, 'end': 11.6},
#   {'start': 15.0, 'end': 16.3},
#   {'start': 19.2, 'end': 20.7},
#   {'start': 25.3, 'end': 26.8},
#   {'start': 29.2, 'end': 29.7},
#   {'start': 29.8, 'end': 30.5},
#   {'start': 35.2, 'end': 36.5},
#   {'start': 39.3, 'end': 40.7},
#   {'start': 44.6, 'end': 45.6},
#   {'start': 49.0, 'end': 50.3}],
#  'banana/XC798995.ogg': [{'start': 3.5, 'end': 3.8},
#   {'start': 4.0, 'end': 4.3},
#   {'start': 4.5, 'end': 5.1},
#   {'start': 9.4, 'end': 9.9},
#   {'start': 10.1, 'end': 11.6},
#   {'start': 13.5, 'end': 14.0},
#   {'start': 14.2, 'end': 15.2}],
#  'banana/XC843257.ogg': [{'start': 2.8, 'end': 3.4},
#   {'start': 81.7, 'end': 82.3},
#   {'start': 82.5, 'end': 83.6},
#   {'start': 84.5, 'end': 87.4},
#   {'start': 87.8, 'end': 88.7},
#   {'start': 89.5, 'end': 91.6},
#   {'start': 91.9, 'end': 94.6},
#   {'start': 96.6, 'end': 98.1},
#   {'start': 98.6, 'end': 99.3},
#   {'start': 100.1, 'end': 101.7},
#   {'start': 102.7, 'end': 105.1},
#   {'start': 107.2, 'end': 109.3}],
#  'banana/XC843854.ogg': [{'start': 1.6, 'end': 2.7}],
#  'banana/XC844249.ogg': [{'start': 38.9, 'end': 39.8},
#   {'start': 40.1, 'end': 44.1},
#   {'start': 44.7, 'end': 45.2},
#   {'start': 45.5, 'end': 49.6},
#   {'start': 49.8, 'end': 50.6}],
#  'banana/XC84790.ogg': [{'start': 4.6, 'end': 5.3},
#   {'start': 6.4, 'end': 7.0},
#   {'start': 7.2, 'end': 8.5},
#   {'start': 8.7, 'end': 10.8},
#   {'start': 12.3, 'end': 13.0},
#   {'start': 13.2, 'end': 14.5},
#   {'start': 16.0, 'end': 16.4},
#   {'start': 17.1, 'end': 17.6},
#   {'start': 17.9, 'end': 18.6},
#   {'start': 18.8, 'end': 19.3},
#   {'start': 19.8, 'end': 20.4},
#   {'start': 23.4, 'end': 23.8}],
#  'banana/XC960258.ogg': [{'start': 48.7, 'end': 52.4},
#   {'start': 52.8, 'end': 54.0},
#   {'start': 54.1, 'end': 54.9}],
#  'banana/iNat1144174.ogg': [{'start': 0.7, 'end': 1.5}],
#  'banana/iNat1192531.ogg': [{'start': 0.1, 'end': 1.4}],
#  'banana/iNat217408.ogg': [{'start': 1.8, 'end': 2.1}],
#  'banana/iNat483177.ogg': [{'start': 6.7, 'end': 7.1},
#   {'start': 7.5, 'end': 7.9},
#   {'start': 9.5, 'end': 9.9},
#   {'start': 11.6, 'end': 13.1}],
#  'banana/iNat678048.ogg': [{'start': 6.8, 'end': 7.9}],
#  'banana/iNat723526.ogg': [{'start': 0.8, 'end': 2.0}],
#  'banana/iNat858225.ogg': [{'start': 12.4, 'end': 12.7}],
#  'banana/iNat863497.ogg': [{'start': 0.6, 'end': 1.9}],
#  'baymac/XC148295.ogg': [{'start': 20.1, 'end': 20.8},
#   {'start': 25.0, 'end': 27.4}],
#  'baymac/XC154003.ogg': [{'start': 26.1, 'end': 29.1},
#   {'start': 29.9, 'end': 30.4},
#   {'start': 30.7, 'end': 33.2},
#   {'start': 34.7, 'end': 36.8},
#   {'start': 39.0, 'end': 40.8},
#   {'start': 45.1, 'end': 47.1},
#   {'start': 48.8, 'end': 50.6},
#   {'start': 50.7, 'end': 53.0},
#   {'start': 53.6, 'end': 57.9},
#   {'start': 58.2, 'end': 62.6},
#   {'start': 63.9, 'end': 68.5},
#   {'start': 70.4, 'end': 70.9}],
#  'baymac/XC155415.ogg': [{'start': 15.0, 'end': 16.1}],
#  'baymac/XC174023.ogg': [{'start': 0.5, 'end': 0.8}],
#  'bbwduc/XC148228.ogg': [{'start': 40.0, 'end': 42.5},
#   {'start': 43.3, 'end': 45.5},
#   {'start': 51.4, 'end': 52.2}],
#  'bbwduc/XC2194.ogg': [{'start': 5.1, 'end': 5.5}],
#  'bbwduc/XC513475.ogg': [{'start': 3.4, 'end': 4.0},
#   {'start': 4.9, 'end': 5.4},
#   {'start': 7.2, 'end': 7.6}],
#  'bbwduc/XC761500.ogg': [{'start': 1.3, 'end': 1.7}],
#  'bbwduc/XC820358.ogg': [{'start': 6.7, 'end': 10.4},
#   {'start': 11.3, 'end': 13.3}],
#  'bbwduc/XC858089.ogg': [{'start': 109.4, 'end': 110.0},
#   {'start': 111.3, 'end': 112.2},
#   {'start': 112.5, 'end': 113.7},
#   {'start': 114.7, 'end': 116.2},
#   {'start': 116.3, 'end': 117.0},
#   {'start': 119.0, 'end': 120.2},
#   {'start': 134.1, 'end': 135.6},
#   {'start': 138.4, 'end': 139.2},
#   {'start': 139.4, 'end': 140.0},
#   {'start': 140.4, 'end': 141.3},
#   {'start': 141.9, 'end': 142.3},
#   {'start': 143.4, 'end': 143.7},
#   {'start': 146.3, 'end': 147.5},
#   {'start': 149.1, 'end': 149.9},
#   {'start': 152.7, 'end': 153.2},
#   {'start': 154.8, 'end': 156.1}],
#  'bbwduc/iNat1018580.ogg': [{'start': 2.9, 'end': 3.4}],
#  'bbwduc/iNat956671.ogg': [{'start': 8.9, 'end': 9.374}],
#  'bicwre1/XC148065.ogg': [{'start': 88.9, 'end': 90.8},
#   {'start': 94.0, 'end': 96.0}],
#  'bicwre1/XC178616.ogg': [{'start': 206.3, 'end': 207.2},
#   {'start': 207.3, 'end': 208.2},
#   {'start': 211.4, 'end': 212.2},
#   {'start': 213.1, 'end': 214.2},
#   {'start': 215.1, 'end': 216.2},
#   {'start': 219.3, 'end': 223.1},
#   {'start': 223.6, 'end': 225.1}],
#  'bicwre1/XC245510.ogg': [{'start': 4.4, 'end': 5.0},
#   {'start': 5.3, 'end': 6.5},
#   {'start': 7.6, 'end': 8.3},
#   {'start': 8.5, 'end': 9.1}],
#  'bicwre1/XC327198.ogg': [{'start': 74.0, 'end': 78.9},
#   {'start': 79.0, 'end': 79.7},
#   {'start': 80.9, 'end': 82.8},
#   {'start': 83.6, 'end': 84.3},
#   {'start': 85.4, 'end': 86.9}],
#  'bicwre1/XC354868.ogg': [{'start': 0.9, 'end': 1.2}],
#  'bicwre1/XC525027.ogg': [{'start': 205.5, 'end': 206.7},
#   {'start': 208.0, 'end': 210.2},
#   {'start': 211.0, 'end': 212.1},
#   {'start': 213.8, 'end': 215.6},
#   {'start': 216.9, 'end': 218.0},
#   {'start': 220.7, 'end': 223.0}],
#  'bicwre1/XC528766.ogg': [{'start': 2.0, 'end': 2.4},
#   {'start': 3.5, 'end': 3.8}],
#  'bicwre1/XC9017.ogg': [{'start': 0.4, 'end': 3.898}],
#  'bicwre1/XC960815.ogg': [{'start': 17.8, 'end': 19.2},
#   {'start': 20.3, 'end': 21.7},
#   {'start': 21.8, 'end': 23.7},
#   {'start': 25.3, 'end': 29.1}],
#  'bkcdon/XC120539.ogg': [{'start': 14.0, 'end': 14.3}],
#  'bkcdon/XC128808.ogg': [{'start': 2.1, 'end': 5.8},
#   {'start': 11.2, 'end': 11.6},
#   {'start': 12.0, 'end': 12.8},
#   {'start': 14.8, 'end': 15.4},
#   {'start': 16.4, 'end': 18.4},
#   {'start': 23.9, 'end': 25.2}],
#  'bkcdon/XC148063.ogg': [{'start': 23.1, 'end': 24.4},
#   {'start': 28.5, 'end': 30.3}],
#  'bkcdon/XC164890.ogg': [{'start': 19.8, 'end': 20.6}],
#  'bkcdon/XC192741.ogg': [{'start': 2.2, 'end': 2.8}],
#  'bkcdon/XC351253.ogg': [{'start': 3.6, 'end': 4.0}],
#  'bkcdon/XC520717.ogg': [{'start': 1.5, 'end': 2.4},
#   {'start': 6.5, 'end': 9.5}],
#  'bkcdon/XC549922.ogg': [{'start': 5.6, 'end': 8.1},
#   {'start': 8.4, 'end': 8.8},
#   {'start': 9.0, 'end': 9.8},
#   {'start': 10.0, 'end': 12.0}],
#  'bkcdon/XC580812.ogg': [{'start': 6.7, 'end': 8.2}],
#  'bkcdon/XC830853.ogg': [{'start': 2.5, 'end': 2.8}],
#  'bkcdon/XC960303.ogg': [{'start': 31.7, 'end': 34.4},
#   {'start': 34.5, 'end': 36.2},
#   {'start': 36.5, 'end': 37.7},
#   {'start': 38.8, 'end': 39.5}],
#  'bkcdon/iNat623494.ogg': [{'start': 0.9, 'end': 1.9}],
#  'bkmtou1/XC117223.ogg': [{'start': 34.0, 'end': 34.3},
#   {'start': 34.5, 'end': 35.1},
#   {'start': 39.7, 'end': 40.1},
#   {'start': 44.5, 'end': 45.7},
#   {'start': 84.1, 'end': 84.8}],
#  'bkmtou1/XC117224.ogg': [{'start': 69.9, 'end': 70.4},
#   {'start': 70.5, 'end': 71.9}],
#  'bkmtou1/XC117323.ogg': [{'start': 84.8, 'end': 87.1}],
#  'bkmtou1/XC117551.ogg': [{'start': 85.4, 'end': 87.8}],
#  'bkmtou1/XC154169.ogg': [{'start': 153.1, 'end': 154.3},
#   {'start': 156.7, 'end': 158.3},
#   {'start': 159.2, 'end': 160.4},
#   {'start': 160.7, 'end': 161.7},
#   {'start': 162.9, 'end': 163.8},
#   {'start': 166.9, 'end': 168.4},
#   {'start': 169.1, 'end': 170.9},
#   {'start': 171.9, 'end': 173.3},
#   {'start': 174.6, 'end': 176.3}],
#  'bkmtou1/XC178178.ogg': [{'start': 2.5, 'end': 3.6}],
#  'bkmtou1/XC199034.ogg': [{'start': 46.2, 'end': 47.2},
#   {'start': 48.8, 'end': 51.4},
#   {'start': 51.9, 'end': 53.7},
#   {'start': 54.4, 'end': 56.1}],
#  'bkmtou1/XC312738.ogg': [{'start': 2.1, 'end': 2.8},
#   {'start': 3.2, 'end': 5.1},
#   {'start': 12.6, 'end': 13.2}],
#  'bkmtou1/XC322084.ogg': [{'start': 151.3, 'end': 152.3},
#   {'start': 152.4, 'end': 155.7},
#   {'start': 156.6, 'end': 158.4},
#   {'start': 158.6, 'end': 159.3},
#   {'start': 160.0, 'end': 161.5},
#   {'start': 161.7, 'end': 162.4},
#   {'start': 162.5, 'end': 164.1}],
#  'bkmtou1/XC331812.ogg': [{'start': 5.8, 'end': 7.0},
#   {'start': 7.7, 'end': 10.6},
#   {'start': 12.6, 'end': 18.0},
#   {'start': 18.4, 'end': 19.8},
#   {'start': 20.0, 'end': 21.0},
#   {'start': 22.5, 'end': 23.3}],
#  'bkmtou1/XC366934.ogg': [{'start': 5.1, 'end': 5.5},
#   {'start': 5.6, 'end': 6.8}],
#  'bkmtou1/XC505784.ogg': [{'start': 78.5, 'end': 80.0},
#   {'start': 80.5, 'end': 81.9},
#   {'start': 83.8, 'end': 84.2},
#   {'start': 86.8, 'end': 88.0},
#   {'start': 101.4, 'end': 101.9}],
#  'bkmtou1/XC518213.ogg': [{'start': 114.6, 'end': 115.3},
#   {'start': 115.5, 'end': 117.0}],
#  'bkmtou1/XC600051.ogg': [{'start': 1.2, 'end': 1.7},
#   {'start': 2.4, 'end': 4.7},
#   {'start': 11.1, 'end': 11.6},
#   {'start': 11.7, 'end': 13.2},
#   {'start': 13.4, 'end': 15.1},
#   {'start': 15.4, 'end': 16.4},
#   {'start': 17.2, 'end': 18.4}],
#  'bkmtou1/iNat1160670.ogg': [{'start': 19.7, 'end': 21.0},
#   {'start': 21.3, 'end': 23.6},
#   {'start': 25.7, 'end': 26.2},
#   {'start': 26.6, 'end': 27.4}],
#  'bkmtou1/iNat1270065.ogg': [{'start': 3.3, 'end': 5.1},
#   {'start': 5.3, 'end': 7.5},
#   {'start': 13.0, 'end': 13.4},
#   {'start': 13.5, 'end': 15.6},
#   {'start': 17.4, 'end': 19.0}],
#  'bkmtou1/iNat737303.ogg': [{'start': 1.9, 'end': 3.6},
#   {'start': 9.4, 'end': 10.0}],
#  'bkmtou1/iNat959239.ogg': [{'start': 4.4, 'end': 6.5},
#   {'start': 7.8, 'end': 8.2}],
#  'blbgra1/XC154030.ogg': [{'start': 63.1, 'end': 64.8},
#   {'start': 67.3, 'end': 69.4},
#   {'start': 69.9, 'end': 70.9}],
#  'blbgra1/XC169970.ogg': [{'start': 1.0, 'end': 1.4},
#   {'start': 8.9, 'end': 9.2}],
#  'blbgra1/XC187799.ogg': [{'start': 4.4, 'end': 4.9}],
#  'blbgra1/XC207618.ogg': [{'start': 14.3, 'end': 17.4}],
#  'blbgra1/XC240066.ogg': [{'start': 10.6, 'end': 12.1},
#   {'start': 13.7, 'end': 14.5},
#   {'start': 16.4, 'end': 17.5},
#   {'start': 18.0, 'end': 19.6},
#   {'start': 20.0, 'end': 20.7},
#   {'start': 21.2, 'end': 22.3}],
#  'blbgra1/XC278144.ogg': [{'start': 1.0, 'end': 1.6},
#   {'start': 4.4, 'end': 4.7}],
#  'blbgra1/XC343213.ogg': [{'start': 2.0, 'end': 2.4}],
#  'blbgra1/XC348692.ogg': [{'start': 0.8, 'end': 1.5},
#   {'start': 2.9, 'end': 3.3},
#   {'start': 4.2, 'end': 4.5}],
#  'blbgra1/XC431634.ogg': [{'start': 1.3, 'end': 3.1},
#   {'start': 4.2, 'end': 5.8},
#   {'start': 6.4, 'end': 9.3},
#   {'start': 10.0, 'end': 12.1},
#   {'start': 12.6, 'end': 15.3},
#   {'start': 16.6, 'end': 20.6},
#   {'start': 21.6, 'end': 24.2},
#   {'start': 24.3, 'end': 25.9},
#   {'start': 26.9, 'end': 28.0},
#   {'start': 28.2, 'end': 28.7},
#   {'start': 28.9, 'end': 30.8},
#   {'start': 31.8, 'end': 35.6},
#   {'start': 37.5, 'end': 39.0},
#   {'start': 40.4, 'end': 42.8},
#   {'start': 44.5, 'end': 45.3},
#   {'start': 50.1, 'end': 52.3},
#   {'start': 53.3, 'end': 54.6},
#   {'start': 55.9, 'end': 56.4},
#   {'start': 56.5, 'end': 57.1},
#   {'start': 57.3, 'end': 59.1}],
#  'blbgra1/XC442386.ogg': [{'start': 4.5, 'end': 5.0},
#   {'start': 6.8, 'end': 7.1},
#   {'start': 9.0, 'end': 10.2},
#   {'start': 10.4, 'end': 13.3}],
#  'blbgra1/XC446769.ogg': [{'start': 2.0, 'end': 2.8}],
#  'blbgra1/XC486813.ogg': [{'start': 1.6, 'end': 1.9},
#   {'start': 4.9, 'end': 5.3}],
#  'blbgra1/XC524135.ogg': [{'start': 42.1, 'end': 44.4}],
#  'blbgra1/XC524136.ogg': [{'start': 61.1, 'end': 61.8},
#   {'start': 67.2, 'end': 69.9}],
#  'blbgra1/XC524138.ogg': [{'start': 91.1, 'end': 92.1},
#   {'start': 94.4, 'end': 94.8},
#   {'start': 96.9, 'end': 99.3}],
#  'blbgra1/XC525025.ogg': [{'start': 14.5, 'end': 15.6},
#   {'start': 129.3, 'end': 129.8},
#   {'start': 131.2, 'end': 133.6}],
#  'blbgra1/XC920984.ogg': [{'start': 1.2, 'end': 1.8},
#   {'start': 2.0, 'end': 2.4}],
#  'blbgra1/iNat376887.ogg': [{'start': 0.8, 'end': 1.3}],
#  'blbgra1/iNat544622.ogg': [{'start': 3.1, 'end': 3.6},
#   {'start': 4.8, 'end': 5.4},
#   {'start': 6.3, 'end': 6.8},
#   {'start': 10.2, 'end': 11.0},
#   {'start': 11.2, 'end': 11.8},
#   {'start': 17.5, 'end': 17.9},
#   {'start': 18.5, 'end': 18.9},
#   {'start': 19.2, 'end': 21.4},
#   {'start': 21.8, 'end': 26.3},
#   {'start': 27.7, 'end': 28.4},
#   {'start': 28.4, 'end': 29.0}],
#  'blbgra1/iNat587282.ogg': [{'start': 0.7, 'end': 1.2}],
#  'blbgra1/iNat811950.ogg': [{'start': 0.2, 'end': 0.7},
#   {'start': 1.4, 'end': 3.0},
#   {'start': 5.7, 'end': 7.3}],
#  'blbwre1/XC148213.ogg': [{'start': 62.2, 'end': 63.3},
#   {'start': 64.3, 'end': 64.7},
#   {'start': 64.9, 'end': 66.0},
#   {'start': 67.2, 'end': 67.6},
#   {'start': 68.5, 'end': 70.0},
#   {'start': 73.5, 'end': 74.7},
#   {'start': 75.1, 'end': 75.9}],
#  'blbwre1/XC148304.ogg': [{'start': 23.0, 'end': 23.8},
#   {'start': 23.9, 'end': 25.0},
#   {'start': 28.4, 'end': 31.4}],
#  'blbwre1/XC148416.ogg': [{'start': 84.9, 'end': 86.2},
#   {'start': 86.6, 'end': 87.1},
#   {'start': 87.7, 'end': 88.0},
#   {'start': 89.2, 'end': 90.5},
#   {'start': 90.9, 'end': 91.2},
#   {'start': 93.0, 'end': 93.5},
#   {'start': 95.7, 'end': 96.2},
#   {'start': 97.9, 'end': 100.0}],
#  'blbwre1/XC386635.ogg': [{'start': 2.8, 'end': 3.5}],
#  'blcant4/XC524071.ogg': [{'start': 7.3, 'end': 7.8},
#   {'start': 8.1, 'end': 8.6},
#   {'start': 11.4, 'end': 13.9}],
#  'blcant4/XC525049.ogg': [{'start': 51.3, 'end': 53.1}],
#  'blcant4/XC825916.ogg': [{'start': 1.5, 'end': 1.9},
#   {'start': 2.5, 'end': 3.7},
#   {'start': 5.2, 'end': 5.5}],
#  'blcant4/XC912382.ogg': [{'start': 7.7, 'end': 8.1},
#   {'start': 8.7, 'end': 9.3},
#   {'start': 9.9, 'end': 10.7}],
#  'blcant4/XC960262.ogg': [{'start': 70.4, 'end': 71.9},
#   {'start': 72.0, 'end': 74.7},
#   {'start': 76.1, 'end': 77.0}],
#  'blcant4/XC960833.ogg': [{'start': 32.0, 'end': 36.4},
#   {'start': 36.6, 'end': 37.8},
#   {'start': 38.6, 'end': 41.0},
#   {'start': 42.3, 'end': 45.8}],
#  'blchaw1/XC148061.ogg': [{'start': 34.0, 'end': 36.3},
#   {'start': 37.5, 'end': 40.2},
#   {'start': 44.5, 'end': 46.0}],
#  'blchaw1/XC264371.ogg': [{'start': 1.7, 'end': 2.4}],
#  'blchaw1/XC353395.ogg': [{'start': 0.4, 'end': 4.3},
#   {'start': 4.8, 'end': 7.666}],
#  'blchaw1/XC414804.ogg': [{'start': 1.7, 'end': 2.1}],
#  'blchaw1/XC657807.ogg': [{'start': 0.9, 'end': 1.4}],
#  'blchaw1/iNat629789.ogg': [{'start': 1.4, 'end': 5.1},
#   {'start': 5.3, 'end': 10.5},
#   {'start': 10.9, 'end': 13.2},
#   {'start': 13.4, 'end': 15.2},
#   {'start': 15.7, 'end': 16.6},
#   {'start': 17.7, 'end': 18.0},
#   {'start': 20.1, 'end': 21.0},
#   {'start': 21.3, 'end': 23.5},
#   {'start': 23.6, 'end': 24.4},
#   {'start': 25.2, 'end': 26.3}],
#  'blcjay1/XC148090.ogg': [{'start': 61.7, 'end': 62.1},
#   {'start': 65.5, 'end': 67.4}],
#  'blcjay1/XC148302.ogg': [{'start': 28.5, 'end': 29.2},
#   {'start': 29.4, 'end': 30.8},
#   {'start': 30.9, 'end': 31.6},
#   {'start': 34.9, 'end': 37.3}],
#  'blcjay1/XC148309.ogg': [{'start': 53.4, 'end': 55.5},
#   {'start': 56.2, 'end': 57.8},
#   {'start': 58.0, 'end': 58.8},
#   {'start': 58.9, 'end': 60.1},
#   {'start': 61.6, 'end': 62.8},
#   {'start': 63.0, 'end': 64.0},
#   {'start': 70.1, 'end': 70.9}],
#  'blcjay1/XC424495.ogg': [{'start': 9.1, 'end': 9.9}],
#  'blcjay1/XC523854.ogg': [{'start': 48.3, 'end': 49.3},
#   {'start': 55.5, 'end': 57.1},
#   {'start': 65.0, 'end': 65.7},
#   {'start': 66.7, 'end': 67.1},
#   {'start': 69.9, 'end': 72.4}],
#  'blcjay1/XC529474.ogg': [{'start': 213.8, 'end': 215.4},
#   {'start': 215.6, 'end': 216.4},
#   {'start': 216.6, 'end': 218.0},
#   {'start': 218.8, 'end': 220.3},
#   {'start': 220.4, 'end': 221.3}],
#  'blcjay1/XC816047.ogg': [{'start': 26.9, 'end': 27.5},
#   {'start': 27.7, 'end': 28.1},
#   {'start': 28.4, 'end': 29.4},
#   {'start': 31.6, 'end': 33.2},
#   {'start': 33.8, 'end': 34.8},
#   {'start': 35.3, 'end': 36.4},
#   {'start': 37.5, 'end': 39.2},
#   {'start': 39.5, 'end': 41.1},
#   {'start': 41.6, 'end': 43.4},
#   {'start': 44.4, 'end': 46.0},
#   {'start': 46.4, 'end': 46.8},
#   {'start': 47.8, 'end': 49.2},
#   {'start': 49.4, 'end': 51.5},
#   {'start': 51.8, 'end': 53.2},
#   {'start': 53.3, 'end': 56.4},
#   {'start': 58.6, 'end': 60.1},
#   {'start': 60.3, 'end': 61.8},
#   {'start': 62.7, 'end': 64.7},
#   {'start': 67.2, 'end': 68.5},
#   {'start': 69.3, 'end': 70.0}],
#  'blcjay1/XC891930.ogg': [{'start': 3.8, 'end': 4.7},
#   {'start': 6.7, 'end': 7.5}],
#  'blctit1/XC142020.ogg': [{'start': 2.3, 'end': 2.6}],
#  'blhpar1/XC117984.ogg': [{'start': 12.6, 'end': 15.4}],
#  'blhpar1/XC148080.ogg': [{'start': 47.5, 'end': 48.1}],
#  'blhpar1/XC148297.ogg': [{'start': 12.6, 'end': 14.1},
#   {'start': 18.1, 'end': 18.9},
#   {'start': 19.3, 'end': 20.5}],
#  'blhpar1/XC174550.ogg': [{'start': 5.2, 'end': 5.6}],
#  'blhpar1/XC238883.ogg': [{'start': 4.5, 'end': 5.0}],
#  'blhpar1/XC407823.ogg': [{'start': 3.3, 'end': 3.8}],
#  'blhpar1/XC460415.ogg': [{'start': 0.6, 'end': 3.5},
#   {'start': 6.0, 'end': 6.6}],
#  'blhpar1/XC518101.ogg': [{'start': 31.6, 'end': 31.9},
#   {'start': 32.0, 'end': 33.1},
#   {'start': 33.8, 'end': 35.5}],
#  'blhpar1/XC518102.ogg': [{'start': 18.1, 'end': 20.0}],
#  'blhpar1/XC521022.ogg': [{'start': 34.3, 'end': 34.7}],
#  'blhpar1/XC521023.ogg': [{'start': 26.2, 'end': 26.6},
#   {'start': 27.4, 'end': 28.3}],
#  'blhpar1/XC525408.ogg': [{'start': 13.6, 'end': 15.4}],
#  'blhpar1/XC529315.ogg': [{'start': 28.2, 'end': 28.6}],
#  'blhpar1/XC532550.ogg': [{'start': 42.2, 'end': 44.3}],
#  'blhpar1/XC532552.ogg': [{'start': 30.0, 'end': 31.6}],
#  'blhpar1/XC689905.ogg': [{'start': 5.1, 'end': 6.0},
#   {'start': 6.5, 'end': 6.9},
#   {'start': 8.0, 'end': 8.5},
#   {'start': 10.4, 'end': 10.7}],
#  'blhpar1/XC810434.ogg': [{'start': 1.6, 'end': 2.3}],
#  'blhpar1/XC825530.ogg': [{'start': 34.1, 'end': 35.7}],
#  'blhpar1/XC828124.ogg': [{'start': 1.2, 'end': 1.6}],
#  'blhpar1/XC835858.ogg': [{'start': 1.8, 'end': 3.4},
#   {'start': 5.2, 'end': 6.0}],
#  'blhpar1/XC882832.ogg': [{'start': 9.4, 'end': 10.2},
#   {'start': 10.7, 'end': 11.3},
#   {'start': 11.9, 'end': 13.9}],
#  'blhpar1/XC932379.ogg': [{'start': 1.8, 'end': 2.1}],
#  'blhpar1/iNat124761.ogg': [{'start': 1.3, 'end': 2.3},
#   {'start': 2.6, 'end': 3.1}],
#  'blkvul/XC154016.ogg': [{'start': 3.6, 'end': 3.9},
#   {'start': 4.2, 'end': 5.3},
#   {'start': 181.0, 'end': 181.7},
#   {'start': 182.9, 'end': 183.5},
#   {'start': 184.5, 'end': 186.7},
#   {'start': 187.4, 'end': 188.2},
#   {'start': 189.1, 'end': 190.1},
#   {'start': 191.8, 'end': 193.1},
#   {'start': 195.9, 'end': 197.9},
#   {'start': 198.7, 'end': 199.8},
#   {'start': 203.0, 'end': 204.5},
#   {'start': 205.6, 'end': 207.4},
#   {'start': 208.9, 'end': 209.6},
#   {'start': 210.5, 'end': 211.2},
#   {'start': 212.2, 'end': 212.8},
#   {'start': 213.0, 'end': 214.3},
#   {'start': 214.7, 'end': 215.8},
#   {'start': 218.0, 'end': 218.3}],
#  'blkvul/XC324803.ogg': [{'start': 5.1, 'end': 5.7}],
#  'blkvul/XC408078.ogg': [{'start': 2.2, 'end': 2.5}],
#  'blkvul/XC48345.ogg': [{'start': 1.7, 'end': 2.1}],
#  'blkvul/XC567305.ogg': [{'start': 1.4, 'end': 1.9},
#   {'start': 3.0, 'end': 3.6}],
#  'blkvul/iNat314840.ogg': [{'start': 0.5, 'end': 0.8}],
#  'bobfly1/XC126338.ogg': [{'start': 1.3, 'end': 3.094}],
#  'bobfly1/XC148193.ogg': [{'start': 42.8, 'end': 43.3},
#   {'start': 54.1, 'end': 56.154}],
#  'bobfly1/XC165473.ogg': [{'start': 59.0, 'end': 61.3},
#   {'start': 63.3, 'end': 64.2}],
#  'bobfly1/XC235872.ogg': [{'start': 25.0, 'end': 25.9}],
#  'bobfly1/XC244952.ogg': [{'start': 1.9, 'end': 3.0}],
#  'bobfly1/XC388081.ogg': [{'start': 0.8, 'end': 1.1}],
#  'bobfly1/XC412072.ogg': [{'start': 21.6, 'end': 22.9},
#   {'start': 23.3, 'end': 23.9},
#   {'start': 24.4, 'end': 25.1}],
#  'bobfly1/XC523949.ogg': [{'start': 47.5, 'end': 48.3},
#   {'start': 49.1, 'end': 50.0},
#   {'start': 50.4, 'end': 51.3},
#   {'start': 52.6, 'end': 53.2},
#   {'start': 53.4, 'end': 54.1},
#   {'start': 54.5, 'end': 55.2},
#   {'start': 55.9, 'end': 56.3},
#   {'start': 59.1, 'end': 61.3}],
#  'bobfly1/XC523951.ogg': [{'start': 44.7, 'end': 45.5},
#   {'start': 47.5, 'end': 48.5},
#   {'start': 50.7, 'end': 51.6},
#   {'start': 52.8, 'end': 55.4}],
#  'bobfly1/XC525047.ogg': [{'start': 11.6, 'end': 13.2},
#   {'start': 15.6, 'end': 18.0}],
#  'bobfly1/XC690557.ogg': [{'start': 2.9, 'end': 3.2},
#   {'start': 3.4, 'end': 3.9}],
#  'bobfly1/XC766337.ogg': [{'start': 0.1, 'end': 0.6}],
#  'bobfly1/XC912301.ogg': [{'start': 97.5, 'end': 98.1},
#   {'start': 98.2, 'end': 98.8},
#   {'start': 100.0, 'end': 104.0},
#   {'start': 104.7, 'end': 105.6},
#   {'start': 105.8, 'end': 106.9},
#   {'start': 107.2, 'end': 107.9},
#   {'start': 108.0, 'end': 109.1},
#   {'start': 109.3, 'end': 111.4},
#   {'start': 112.7, 'end': 113.7},
#   {'start': 114.8, 'end': 117.6}],
#  'bobfly1/XC925739.ogg': [{'start': 14.1, 'end': 14.8}],
#  'bobfly1/iNat1268958.ogg': [{'start': 0.4, 'end': 1.0}],
#  'bobfly1/iNat277445.ogg': [{'start': 45.6, 'end': 46.0}],
#  'bobfly1/iNat761496.ogg': [{'start': 7.8, 'end': 8.3},
#   {'start': 9.4, 'end': 10.0}],
#  'bobfly1/iNat864102.ogg': [{'start': 3.6, 'end': 4.0}],
#  'bobher1/XC116107.ogg': [{'start': 3.9, 'end': 5.9}],
#  'bobher1/XC166160.ogg': [{'start': 0.3, 'end': 3.2},
#   {'start': 3.7, 'end': 5.5}],
#  'bobher1/XC221003.ogg': [{'start': 0.8, 'end': 2.3}],
#  'bobher1/XC225320.ogg': [{'start': 0.5, 'end': 1.1},
#   {'start': 2.9, 'end': 3.2},
#   {'start': 3.4, 'end': 3.7},
#   {'start': 4.2, 'end': 5.0}],
#  'bobher1/XC238142.ogg': [{'start': 19.9, 'end': 20.3}],
#  'bobher1/XC244877.ogg': [{'start': 4.9, 'end': 5.4},
#   {'start': 6.0, 'end': 8.9},
#   {'start': 40.7, 'end': 41.0},
#   {'start': 41.5, 'end': 42.0},
#   {'start': 193.6, 'end': 194.3},
#   {'start': 194.8, 'end': 198.7},
#   {'start': 198.9, 'end': 200.5},
#   {'start': 200.9, 'end': 201.6}],
#  'bobher1/XC441049.ogg': [{'start': 0.3, 'end': 3.1}],
#  'bobher1/XC623980.ogg': [{'start': 1.0, 'end': 2.1}],
#  'bobher1/XC654332.ogg': [{'start': 0.7, 'end': 1.5}],
#  'bobher1/XC657819.ogg': [{'start': 1.9, 'end': 2.3},
#   {'start': 2.8, 'end': 3.6}],
#  'bobher1/XC694757.ogg': [{'start': 1.6, 'end': 1.9}],
#  'brtpar1/XC144925.ogg': [{'start': 11.5, 'end': 12.9},
#   {'start': 13.2, 'end': 15.5}],
#  'brtpar1/XC148056.ogg': [{'start': 20.4, 'end': 21.2},
#   {'start': 21.5, 'end': 22.0},
#   {'start': 26.3, 'end': 27.6}],
#  'brtpar1/XC244889.ogg': [{'start': 0.7, 'end': 1.1}],
#  'brtpar1/XC245447.ogg': [{'start': 1.2, 'end': 4.9}],
#  'brtpar1/XC43804.ogg': [{'start': 2.3, 'end': 3.0},
#   {'start': 5.7, 'end': 6.0}],
#  'brtpar1/XC46861.ogg': [{'start': 9.8, 'end': 10.3}],
#  'brtpar1/XC525036.ogg': [{'start': 77.7, 'end': 78.8},
#   {'start': 81.4, 'end': 83.7}],
#  'brtpar1/XC820346.ogg': [{'start': 23.5, 'end': 26.7}],
#  'bubwre1/XC117310.ogg': [{'start': 9.7, 'end': 11.7}],
#  'bubwre1/XC148054.ogg': [{'start': 37.3, 'end': 38.8},
#   {'start': 43.7, 'end': 45.1}],
#  'bubwre1/XC148327.ogg': [{'start': 52.3, 'end': 54.8},
#   {'start': 60.9, 'end': 61.7}],
#  'bubwre1/XC152235.ogg': [{'start': 0.1, 'end': 0.4},
#   {'start': 60.2, 'end': 60.7},
#   {'start': 60.8, 'end': 61.4},
#   {'start': 61.6, 'end': 62.3}],
#  'bubwre1/XC154170.ogg': [{'start': 33.7, 'end': 35.1},
#   {'start': 35.2, 'end': 35.9},
#   {'start': 36.7, 'end': 37.5},
#   {'start': 38.1, 'end': 39.8},
#   {'start': 41.4, 'end': 41.9},
#   {'start': 42.6, 'end': 44.4},
#   {'start': 45.1, 'end': 48.8},
#   {'start': 50.7, 'end': 51.2},
#   {'start': 51.4, 'end': 55.0},
#   {'start': 58.5, 'end': 59.5},
#   {'start': 60.2, 'end': 61.4},
#   {'start': 61.7, 'end': 63.4},
#   {'start': 63.7, 'end': 65.6},
#   {'start': 66.1, 'end': 67.7},
#   {'start': 69.1, 'end': 73.3}],
#  'bubwre1/XC186097.ogg': [{'start': 1.2, 'end': 5.4},
#   {'start': 5.6, 'end': 6.6}],
#  'bubwre1/XC199016.ogg': [{'start': 53.3, 'end': 54.0},
#   {'start': 54.3, 'end': 54.9},
#   {'start': 55.1, 'end': 56.8},
#   {'start': 59.9, 'end': 60.9},
#   {'start': 62.7, 'end': 64.2},
#   {'start': 65.1, 'end': 67.3},
#   {'start': 68.2, 'end': 69.0},
#   {'start': 70.1, 'end': 72.7},
#   {'start': 74.1, 'end': 75.5}],
#  'bubwre1/XC202249.ogg': [{'start': 1.6, 'end': 2.2},
#   {'start': 2.7, 'end': 3.1}],
#  'bubwre1/XC254204.ogg': [{'start': 23.2, 'end': 25.0},
#   {'start': 28.7, 'end': 30.3}],
#  'bubwre1/XC293833.ogg': [{'start': 6.5, 'end': 6.9}],
#  'bubwre1/XC46862.ogg': [{'start': 0.9, 'end': 1.2},
#   {'start': 1.5, 'end': 2.2}],
#  'bubwre1/XC523782.ogg': [{'start': 54.9, 'end': 55.5},
#   {'start': 56.2, 'end': 57.1},
#   {'start': 60.8, 'end': 63.4}],
#  'bubwre1/XC523784.ogg': [{'start': 64.8, 'end': 65.6},
#   {'start': 65.8, 'end': 67.1},
#   {'start': 72.4, 'end': 74.7}],
#  'bubwre1/XC529503.ogg': [{'start': 90.0, 'end': 90.3},
#   {'start': 94.9, 'end': 95.8}],
#  'bubwre1/XC785696.ogg': [{'start': 0.6, 'end': 1.0}],
#  'bubwre1/XC959960.ogg': [{'start': 45.8, 'end': 47.7},
#   {'start': 48.5, 'end': 49.6},
#   {'start': 50.0, 'end': 51.0},
#   {'start': 52.2, 'end': 54.3}],
#  'bucmot3/XC428327.ogg': [{'start': 0.9, 'end': 1.4},
#   {'start': 6.9, 'end': 7.3}],
#  'bucmot3/XC523956.ogg': [{'start': 252.7, 'end': 253.1},
#   {'start': 253.8, 'end': 254.2},
#   {'start': 260.0, 'end': 262.1}],
#  'bucmot3/XC523957.ogg': [{'start': 29.2, 'end': 31.7}],
#  'bucmot3/XC599783.ogg': [{'start': 0.6, 'end': 1.1}],
#  'bugtan/XC112883.ogg': [{'start': 1.6, 'end': 2.3},
#   {'start': 3.5, 'end': 4.6}],
#  'bugtan/XC137790.ogg': [{'start': 4.6, 'end': 6.1}],
#  'bugtan/XC209776.ogg': [{'start': 2.1, 'end': 2.9},
#   {'start': 5.5, 'end': 5.9}],
#  'bugtan/XC213745.ogg': [{'start': 25.5, 'end': 26.3}],
#  'bugtan/XC243186.ogg': [{'start': 21.9, 'end': 22.7}],
#  'bugtan/XC245125.ogg': [{'start': 5.2, 'end': 6.0}],
#  'bugtan/XC340081.ogg': [{'start': 117.8, 'end': 118.1}],
#  'bugtan/XC363467.ogg': [{'start': 10.4, 'end': 10.8},
#   {'start': 15.6, 'end': 16.5}],
#  'bugtan/XC529585.ogg': [{'start': 35.7, 'end': 36.5},
#   {'start': 62.9, 'end': 64.7}],
#  'bugtan/XC533160.ogg': [{'start': 15.9, 'end': 17.9}],
#  'bugtan/XC549995.ogg': [{'start': 3.2, 'end': 3.6},
#   {'start': 4.1, 'end': 4.5},
#   {'start': 9.7, 'end': 10.2}],
#  'bugtan/XC664437.ogg': [{'start': 2.6, 'end': 3.0}],
#  'bugtan/XC959312.ogg': [{'start': 0.9, 'end': 1.6},
#   {'start': 3.8, 'end': 4.2}],
#  'bugtan/iNat202824.ogg': [{'start': 0.3, 'end': 0.9}],
#  'bugtan/iNat319566.ogg': [{'start': 0.9, 'end': 2.2}],
#  'bugtan/iNat576820.ogg': [{'start': 0.6, 'end': 1.4}],
#  'bugtan/iNat75712.ogg': [{'start': 0.1, 'end': 0.4},
#   {'start': 2.0, 'end': 2.9},
#   {'start': 10.3, 'end': 10.9}],
#  'butsal1/XC153984.ogg': [{'start': 150.1, 'end': 151.1},
#   {'start': 152.6, 'end': 154.3},
#   {'start': 156.7, 'end': 158.3},
#   {'start': 158.9, 'end': 160.9}],
#  'butsal1/XC154126.ogg': [{'start': 165.7, 'end': 167.0},
#   {'start': 168.2, 'end': 171.3},
#   {'start': 172.2, 'end': 174.7},
#   {'start': 177.7, 'end': 179.4},
#   {'start': 180.3, 'end': 182.9},
#   {'start': 185.2, 'end': 187.6},
#   {'start': 188.4, 'end': 189.9}],
#  'butsal1/XC166424.ogg': [{'start': 1.3, 'end': 1.9},
#   {'start': 4.5, 'end': 4.9}],
#  'butsal1/XC236092.ogg': [{'start': 1.7, 'end': 3.3}],
#  'butsal1/XC245513.ogg': [{'start': 2.4, 'end': 3.8}],
#  'butsal1/XC251476.ogg': [{'start': 3.8, 'end': 5.0}],
#  'butsal1/XC289762.ogg': [{'start': 4.0, 'end': 4.5},
#   {'start': 11.0, 'end': 11.9}],
#  'butsal1/XC489625.ogg': [{'start': 5.4, 'end': 5.8},
#   {'start': 7.4, 'end': 8.3}],
#  'butsal1/XC669573.ogg': [{'start': 1.7, 'end': 2.5}],
#  'cargra1/XC144927.ogg': [{'start': 0.6, 'end': 0.9},
#   {'start': 23.7, 'end': 25.6},
#   {'start': 25.9, 'end': 27.5},
#   {'start': 28.0, 'end': 29.7},
#   {'start': 30.1, 'end': 31.0},
#   {'start': 31.1, 'end': 31.8},
#   {'start': 32.5, 'end': 33.4},
#   {'start': 36.6, 'end': 38.4},
#   {'start': 45.7, 'end': 46.2}],
#  'cargra1/XC245501.ogg': [{'start': 49.0, 'end': 49.6},
#   {'start': 49.7, 'end': 50.4}],
#  'cargra1/XC387190.ogg': [{'start': 5.6, 'end': 5.9}],
#  'cargra1/XC387950.ogg': [{'start': 7.7, 'end': 8.0}],
#  'cargra1/XC402575.ogg': [{'start': 14.8, 'end': 18.2},
#   {'start': 18.9, 'end': 19.8},
#   {'start': 20.6, 'end': 21.3}],
#  'cargra1/XC418798.ogg': [{'start': 1.0, 'end': 1.4}],
#  'cargra1/XC420719.ogg': [{'start': 0.1, 'end': 1.2}],
#  'cargra1/iNat1042429.ogg': [{'start': 14.8, 'end': 15.4}],
#  'cargra1/iNat338482.ogg': [{'start': 2.2, 'end': 3.8}],
#  'cargra1/iNat446035.ogg': [{'start': 2.1, 'end': 3.1},
#   {'start': 5.5, 'end': 6.2},
#   {'start': 10.5, 'end': 10.8}],
#  'cargra1/iNat66186.ogg': [{'start': 0.9, 'end': 1.4}],
#  'cargra1/iNat969137.ogg': [{'start': 1.0, 'end': 1.4},
#   {'start': 1.6, 'end': 4.1},
#   {'start': 4.5, 'end': 6.5},
#   {'start': 6.9, 'end': 9.4},
#   {'start': 9.8, 'end': 11.2},
#   {'start': 11.7, 'end': 13.2},
#   {'start': 13.4, 'end': 16.5},
#   {'start': 17.1, 'end': 19.0},
#   {'start': 20.1, 'end': 21.0},
#   {'start': 21.2, 'end': 25.9},
#   {'start': 26.1, 'end': 30.3},
#   {'start': 30.4, 'end': 31.7},
#   {'start': 32.3, 'end': 40.0},
#   {'start': 40.1, 'end': 41.0},
#   {'start': 41.4, 'end': 47.7},
#   {'start': 48.1, 'end': 48.9},
#   {'start': 49.2, 'end': 53.8},
#   {'start': 55.4, 'end': 55.7},
#   {'start': 56.5, 'end': 57.3},
#   {'start': 58.0, 'end': 58.7},
#   {'start': 59.1, 'end': 60.2},
#   {'start': 60.9, 'end': 62.3},
#   {'start': 62.6, 'end': 64.6},
#   {'start': 65.5, 'end': 66.1},
#   {'start': 66.3, 'end': 67.3},
#   {'start': 68.5, 'end': 75.5},
#   {'start': 76.0, 'end': 76.8},
#   {'start': 77.4, 'end': 79.4},
#   {'start': 80.6, 'end': 84.0},
#   {'start': 84.1, 'end': 85.0},
#   {'start': 85.7, 'end': 88.1},
#   {'start': 88.3, 'end': 88.9},
#   {'start': 89.1, 'end': 92.4},
#   {'start': 92.5, 'end': 97.9},
#   {'start': 98.1, 'end': 99.5},
#   {'start': 99.6, 'end': 103.0},
#   {'start': 104.0, 'end': 106.8},
#   {'start': 107.2, 'end': 107.7},
#   {'start': 107.8, 'end': 113.4},
#   {'start': 114.1, 'end': 118.5},
#   {'start': 118.6, 'end': 121.8},
#   {'start': 122.1, 'end': 123.9},
#   {'start': 124.8, 'end': 126.0},
#   {'start': 126.4, 'end': 127.3},
#   {'start': 127.7, 'end': 128.3},
#   {'start': 128.4, 'end': 134.3},
#   {'start': 134.4, 'end': 138.1},
#   {'start': 138.9, 'end': 140.3},
#   {'start': 140.8, 'end': 143.1},
#   {'start': 144.2, 'end': 145.1},
#   {'start': 147.3, 'end': 147.9},
#   {'start': 148.2, 'end': 150.0},
#   {'start': 150.7, 'end': 152.0},
#   {'start': 152.5, 'end': 155.9},
#   {'start': 156.1, 'end': 157.5},
#   {'start': 158.0, 'end': 159.1},
#   {'start': 159.6, 'end': 161.1},
#   {'start': 161.6, 'end': 163.1},
#   {'start': 163.4, 'end': 164.4},
#   {'start': 164.5, 'end': 166.2},
#   {'start': 167.3, 'end': 168.3},
#   {'start': 168.6, 'end': 170.8},
#   {'start': 171.0, 'end': 172.1},
#   {'start': 172.5, 'end': 174.6},
#   {'start': 178.2, 'end': 179.0},
#   {'start': 179.5, 'end': 182.1},
#   {'start': 182.8, 'end': 183.7},
#   {'start': 184.6, 'end': 187.5},
#   {'start': 187.7, 'end': 190.5},
#   {'start': 191.0, 'end': 192.8},
#   {'start': 193.6, 'end': 195.1},
#   {'start': 195.2, 'end': 203.5},
#   {'start': 203.9, 'end': 206.2},
#   {'start': 206.4, 'end': 217.3},
#   {'start': 217.7, 'end': 219.9},
#   {'start': 220.0, 'end': 222.7},
#   {'start': 223.1, 'end': 225.5},
#   {'start': 225.8, 'end': 228.6},
#   {'start': 228.7, 'end': 230.5},
#   {'start': 230.7, 'end': 231.0},
#   {'start': 231.5, 'end': 236.4},
#   {'start': 237.3, 'end': 239.9},
#   {'start': 240.1, 'end': 243.2},
#   {'start': 243.3, 'end': 247.4},
#   {'start': 248.0, 'end': 249.4},
#   {'start': 249.9, 'end': 255.8},
#   {'start': 256.1, 'end': 257.2},
#   {'start': 257.6, 'end': 261.3},
#   {'start': 261.9, 'end': 267.1},
#   {'start': 267.3, 'end': 268.7},
#   {'start': 268.9, 'end': 275.8},
#   {'start': 276.1, 'end': 276.5},
#   {'start': 276.7, 'end': 277.3},
#   {'start': 278.0, 'end': 282.7},
#   {'start': 282.9, 'end': 289.2},
#   {'start': 289.5, 'end': 289.8},
#   {'start': 290.8, 'end': 295.5},
#   {'start': 295.6, 'end': 299.3},
#   {'start': 299.5, 'end': 301.9},
#   {'start': 302.1, 'end': 312.4},
#   {'start': 312.5, 'end': 319.5},
#   {'start': 319.6, 'end': 320.4},
#   {'start': 320.5, 'end': 322.0},
#   {'start': 322.1, 'end': 330.6},
#   {'start': 330.7, 'end': 333.3},
#   {'start': 334.0, 'end': 344.4},
#   {'start': 344.8, 'end': 346.3},
#   {'start': 346.9, 'end': 347.7},
#   {'start': 348.1, 'end': 353.2},
#   {'start': 354.2, 'end': 360.2},
#   {'start': 360.3, 'end': 362.5},
#   {'start': 362.6, 'end': 371.0},
#   {'start': 371.1, 'end': 378.7},
#   {'start': 378.8, 'end': 379.7},
#   {'start': 381.2, 'end': 381.7},
#   {'start': 381.8, 'end': 383.2},
#   {'start': 383.4, 'end': 387.7},
#   {'start': 387.9, 'end': 390.5},
#   {'start': 390.6, 'end': 391.1},
#   {'start': 391.7, 'end': 394.0},
#   {'start': 394.5, 'end': 398.7},
#   {'start': 399.0, 'end': 400.5},
#   {'start': 401.7, 'end': 403.4},
#   {'start': 403.5, 'end': 404.3},
#   {'start': 406.7, 'end': 410.9},
#   {'start': 411.4, 'end': 413.4},
#   {'start': 414.3, 'end': 415.8},
#   {'start': 417.6, 'end': 418.9},
#   {'start': 420.2, 'end': 423.1},
#   {'start': 423.9, 'end': 425.8},
#   {'start': 426.2, 'end': 432.8},
#   {'start': 433.3, 'end': 440.9},
#   {'start': 441.1, 'end': 443.8},
#   {'start': 444.5, 'end': 446.2},
#   {'start': 446.5, 'end': 447.8},
#   {'start': 447.9, 'end': 455.0},
#   {'start': 455.1, 'end': 456.5},
#   {'start': 457.0, 'end': 457.5},
#   {'start': 457.9, 'end': 460.8},
#   {'start': 461.4, 'end': 468.4},
#   {'start': 468.7, 'end': 474.9},
#   {'start': 475.0, 'end': 476.6},
#   {'start': 476.7, 'end': 483.2},
#   {'start': 483.7, 'end': 491.4},
#   {'start': 491.7, 'end': 497.3},
#   {'start': 497.5, 'end': 500.1},
#   {'start': 500.2, 'end': 504.2},
#   {'start': 506.5, 'end': 510.3},
#   {'start': 510.5, 'end': 510.9},
#   {'start': 512.1, 'end': 513.1},
#   {'start': 513.7, 'end': 520.3},
#   {'start': 520.6, 'end': 525.6},
#   {'start': 525.8, 'end': 531.2},
#   {'start': 531.5, 'end': 532.4},
#   {'start': 532.8, 'end': 533.9},
#   {'start': 534.1, 'end': 534.6},
#   {'start': 534.7, 'end': 537.9},
#   {'start': 538.3, 'end': 542.4},
#   {'start': 542.8, 'end': 543.4},
#   {'start': 543.6, 'end': 546.1},
#   {'start': 546.5, 'end': 549.2},
#   {'start': 549.3, 'end': 550.7},
#   {'start': 551.0, 'end': 552.1},
#   {'start': 552.3, 'end': 553.7},
#   {'start': 553.8, 'end': 554.3},
#   {'start': 554.6, 'end': 555.4},
#   {'start': 556.2, 'end': 559.586}],
#  'cattyr/XC119877.ogg': [{'start': 3.6, 'end': 4.0}],
#  'cattyr/XC319746.ogg': [{'start': 0.5, 'end': 1.1},
#   {'start': 1.4, 'end': 1.9},
#   {'start': 2.3, 'end': 2.9},
#   {'start': 3.0, 'end': 5.5}],
#  'chbant1/XC153965.ogg': [{'start': 200.1, 'end': 200.9},
#   {'start': 202.1, 'end': 203.5},
#   {'start': 204.2, 'end': 205.8},
#   {'start': 206.6, 'end': 207.7},
#   {'start': 209.0, 'end': 210.1},
#   {'start': 210.6, 'end': 211.6},
#   {'start': 212.4, 'end': 213.9},
#   {'start': 216.2, 'end': 216.7},
#   {'start': 217.2, 'end': 217.9},
#   {'start': 218.0, 'end': 220.2},
#   {'start': 220.8, 'end': 222.1}],
#  'chbant1/XC153979.ogg': [{'start': 190.0, 'end': 190.4},
#   {'start': 191.2, 'end': 192.5}],
#  'chbant1/XC154043.ogg': [{'start': 12.3, 'end': 15.2},
#   {'start': 16.4, 'end': 17.2},
#   {'start': 17.8, 'end': 19.1},
#   {'start': 20.5, 'end': 24.0},
#   {'start': 25.2, 'end': 27.2},
#   {'start': 27.3, 'end': 30.0}],
#  'chbant1/XC199004.ogg': [{'start': 37.3, 'end': 38.0},
#   {'start': 39.0, 'end': 41.0},
#   {'start': 43.6, 'end': 44.9}],
#  'chbant1/XC244810.ogg': [{'start': 173.8, 'end': 174.6},
#   {'start': 176.2, 'end': 177.7},
#   {'start': 179.1, 'end': 181.0},
#   {'start': 181.1, 'end': 181.9},
#   {'start': 183.9, 'end': 184.5},
#   {'start': 185.8, 'end': 186.4}],
#  'chbant1/XC315057.ogg': [{'start': 26.8, 'end': 28.2}],
#  'chbant1/XC46870.ogg': [{'start': 4.8, 'end': 5.6}],
#  'chbant1/XC474443.ogg': [{'start': 1.2, 'end': 2.0}],
#  'chbant1/XC694917.ogg': [{'start': 103.1, 'end': 104.3},
#   {'start': 104.7, 'end': 106.1},
#   {'start': 108.8, 'end': 109.3},
#   {'start': 109.8, 'end': 110.6},
#   {'start': 111.2, 'end': 112.1},
#   {'start': 112.9, 'end': 114.5},
#   {'start': 116.1, 'end': 116.6},
#   {'start': 119.2, 'end': 119.7},
#   {'start': 120.0, 'end': 120.5},
#   {'start': 122.0, 'end': 122.6},
#   {'start': 123.1, 'end': 123.9},
#   {'start': 124.4, 'end': 125.2},
#   {'start': 126.4, 'end': 127.0},
#   {'start': 128.3, 'end': 128.7}],
#  'chbant1/XC878980.ogg': [{'start': 21.9, 'end': 22.3},
#   {'start': 22.4, 'end': 22.8},
#   {'start': 24.4, 'end': 25.7}],
#  'chbant1/XC958130.ogg': [{'start': 2.7, 'end': 4.5},
#   {'start': 5.5, 'end': 6.7},
#   {'start': 7.1, 'end': 8.1}],
#  'chbant1/iNat1234133.ogg': [{'start': 6.9, 'end': 7.2},
#   {'start': 12.0, 'end': 13.0},
#   {'start': 13.2, 'end': 14.464}],
#  'chbant1/iNat21259.ogg': [{'start': 7.7, 'end': 9.2},
#   {'start': 21.3, 'end': 22.0}],
#  'chbant1/iNat922630.ogg': [{'start': 1.8, 'end': 2.8},
#   {'start': 7.7, 'end': 8.5}],
#  'chfmac1/XC148068.ogg': [{'start': 18.3, 'end': 19.2},
#   {'start': 22.9, 'end': 25.0}],
#  'chfmac1/XC148294.ogg': [{'start': 20.2, 'end': 21.0},
#   {'start': 26.6, 'end': 27.4}],
#  'chfmac1/XC148326.ogg': [{'start': 7.1, 'end': 8.8},
#   {'start': 12.4, 'end': 13.2},
#   {'start': 13.5, 'end': 14.8}],
#  'chfmac1/XC820348.ogg': [{'start': 0.0, 'end': 0.4},
#   {'start': 2.2, 'end': 3.1},
#   {'start': 11.6, 'end': 12.0}],
#  'cinbec1/XC389682.ogg': [{'start': 0.1, 'end': 1.3},
#   {'start': 2.4, 'end': 3.582}],
#  'cocher1/XC116248.ogg': [{'start': 3.4, 'end': 3.7}],
#  'cocher1/XC117045.ogg': [{'start': 99.7, 'end': 101.5}],
#  'cocher1/XC567645.ogg': [{'start': 1.6, 'end': 1.9},
#   {'start': 2.1, 'end': 2.5},
#   {'start': 6.8, 'end': 7.1},
#   {'start': 7.3, 'end': 7.6}],
#  'cocher1/XC580864.ogg': [{'start': 4.4, 'end': 5.3}],
#  'cocher1/XC807349.ogg': [{'start': 8.1, 'end': 8.9}],
#  'cocwoo1/XC117987.ogg': [{'start': 96.9, 'end': 97.3},
#   {'start': 98.0, 'end': 98.8}],
#  'cocwoo1/XC298281.ogg': [{'start': 6.6, 'end': 7.2}],
#  'cocwoo1/XC313261.ogg': [{'start': 5.5, 'end': 6.1}],
#  'cocwoo1/XC880434.ogg': [{'start': 0.9, 'end': 2.1}],
#  'cocwoo1/iNat1165437.ogg': [{'start': 0.2, 'end': 0.7},
#   {'start': 0.8, 'end': 2.2},
#   {'start': 12.4, 'end': 12.8}],
#  'cocwoo1/iNat928976.ogg': [{'start': 2.9, 'end': 3.5}],
#  'colara1/XC154157.ogg': [{'start': 38.0, 'end': 39.0},
#   {'start': 43.7, 'end': 44.8},
#   {'start': 47.8, 'end': 48.4},
#   {'start': 49.8, 'end': 52.0},
#   {'start': 52.7, 'end': 54.0},
#   {'start': 54.4, 'end': 57.3},
#   {'start': 57.7, 'end': 58.5},
#   {'start': 59.5, 'end': 61.4},
#   {'start': 62.8, 'end': 65.0},
#   {'start': 65.7, 'end': 66.3},
#   {'start': 66.5, 'end': 69.3},
#   {'start': 69.4, 'end': 71.0},
#   {'start': 71.3, 'end': 74.6},
#   {'start': 75.5, 'end': 77.4},
#   {'start': 78.1, 'end': 80.5}],
#  'colara1/XC312928.ogg': [{'start': 1.4, 'end': 2.9},
#   {'start': 3.0, 'end': 3.8},
#   {'start': 4.6, 'end': 5.0}],
#  'colara1/XC358315.ogg': [{'start': 47.7, 'end': 49.9}],
# ...
#  'rutjac1/XC186942.ogg': [{'start': 11.7, 'end': 12.3}],
#  'rutjac1/XC250854.ogg': [{'start': 40.7, 'end': 41.2},
#   {'start': 42.2, 'end': 43.8},
#   {'start': 51.9, 'end': 52.5},
#   {'start': 54.0, 'end': 54.6}],
#  'rutjac1/XC276006.ogg': [{'start': 0.2, 'end': 0.5}],
#  'rutjac1/XC289690.ogg': [{'start': 13.6, 'end': 17.3},
#   {'start': 18.1, 'end': 24.1}],
#  'rutjac1/XC382459.ogg': [{'start': 1.2, 'end': 1.8}],
#  'rutjac1/XC389685.ogg': [{'start': 1.2, 'end': 1.7}],
#  'rutjac1/XC427403.ogg': [{'start': 4.6, 'end': 5.1}],
#  'rutjac1/XC452471.ogg': [{'start': 2.0, 'end': 2.5}],
#  'rutpuf1/XC525046.ogg': [{'start': 40.3, 'end': 42.3}],
#  'saffin/XC148218.ogg': [{'start': 8.6, 'end': 10.4},
#   {'start': 14.0, 'end': 14.8},
#   {'start': 15.4, 'end': 16.3}],
#  'saffin/XC314166.ogg': [{'start': 0.8, 'end': 1.3}],
#  'saffin/XC455166.ogg': [{'start': 2.3, 'end': 2.8}],
#  'saffin/XC64186.ogg': [{'start': 92.3, 'end': 92.6}],
#  'saffin/XC774816.ogg': [{'start': 0.6, 'end': 1.1}],
#  'saffin/XC842650.ogg': [{'start': 15.7, 'end': 16.0}],
#  'saffin/XC843995.ogg': [{'start': 133.8, 'end': 134.5},
#   {'start': 135.7, 'end': 136.2},
#   {'start': 136.6, 'end': 137.6},
#   {'start': 138.7, 'end': 141.4},
#   {'start': 142.6, 'end': 142.9},
#   {'start': 143.0, 'end': 143.7},
#   {'start': 145.2, 'end': 146.2},
#   {'start': 146.4, 'end': 147.1},
#   {'start': 147.5, 'end': 149.8},
#   {'start': 150.7, 'end': 151.3},
#   {'start': 151.9, 'end': 154.8},
#   {'start': 155.8, 'end': 160.0},
#   {'start': 162.4, 'end': 163.0}],
#  'saffin/XC879458.ogg': [{'start': 1.1, 'end': 1.7},
#   {'start': 2.1, 'end': 2.5}],
#  'saffin/XC959535.ogg': [{'start': 37.9, 'end': 41.0},
#   {'start': 41.1, 'end': 42.6},
#   {'start': 43.1, 'end': 46.4},
#   {'start': 46.5, 'end': 47.9},
#   {'start': 48.5, 'end': 49.2},
#   {'start': 49.7, 'end': 50.6}],
#  'saffin/iNat1017760.ogg': [{'start': 2.5, 'end': 3.1},
#   {'start': 5.6, 'end': 6.2},
#   {'start': 7.7, 'end': 8.1},
#   {'start': 8.5, 'end': 8.9}],
#  'saffin/iNat1224380.ogg': [{'start': 0.2, 'end': 0.6}],
#  'saffin/iNat1243758.ogg': [{'start': 0.7, 'end': 1.1}],
#  'saffin/iNat1258307.ogg': [{'start': 0.0, 'end': 0.4}],
#  'saffin/iNat307815.ogg': [{'start': 0.7, 'end': 2.1},
#   {'start': 2.4, 'end': 5.6},
#   {'start': 6.4, 'end': 9.1},
#   {'start': 9.5, 'end': 12.7},
#   {'start': 13.2, 'end': 15.4},
#   {'start': 15.8, 'end': 17.7},
#   {'start': 18.3, 'end': 19.8},
#   {'start': 20.0, 'end': 22.8},
#   {'start': 23.1, 'end': 25.0},
#   {'start': 25.2, 'end': 27.4},
#   {'start': 28.4, 'end': 32.3},
#   {'start': 32.5, 'end': 34.2},
#   {'start': 34.6, 'end': 36.6},
#   {'start': 37.2, 'end': 40.4},
#   {'start': 41.0, 'end': 44.2},
#   {'start': 45.1, 'end': 46.8},
#   {'start': 47.1, 'end': 49.4},
#   {'start': 50.1, 'end': 54.2},
#   {'start': 54.9, 'end': 58.0},
#   {'start': 58.4, 'end': 59.5},
#   {'start': 59.8, 'end': 62.1},
#   {'start': 62.2, 'end': 63.4}],
#  'saffin/iNat333543.ogg': [{'start': 0.2, 'end': 1.8},
#   {'start': 2.2, 'end': 2.6},
#   {'start': 2.7, 'end': 4.8},
#   {'start': 5.7, 'end': 7.2},
#   {'start': 7.6, 'end': 8.5}],
#  'saffin/iNat353849.ogg': [{'start': 0.6, 'end': 2.0}],
#  'saffin/iNat588719.ogg': [{'start': 1.0, 'end': 2.8},
#   {'start': 3.0, 'end': 3.5},
#   {'start': 3.8, 'end': 4.6},
#   {'start': 5.3, 'end': 6.4}],
#  'saffin/iNat858660.ogg': [{'start': 12.5, 'end': 13.4}],
#  'saffin/iNat988640.ogg': [{'start': 3.5, 'end': 4.0},
#   {'start': 6.0, 'end': 6.7}],
#  'sahpar1/XC178654.ogg': [{'start': 1.9, 'end': 2.2}],
#  'sahpar1/XC402590.ogg': [{'start': 25.9, 'end': 26.8},
#   {'start': 26.9, 'end': 28.5},
#   {'start': 29.5, 'end': 31.4},
#   {'start': 32.2, 'end': 33.1}],
#  'savhaw1/XC117952.ogg': [{'start': 14.6, 'end': 16.2},
#   {'start': 17.0, 'end': 18.2},
#   {'start': 18.6, 'end': 19.5},
#   {'start': 20.4, 'end': 21.7},
#   {'start': 21.8, 'end': 23.2},
#   {'start': 24.5, 'end': 25.4},
#   {'start': 25.9, 'end': 28.2},
#   {'start': 29.2, 'end': 33.1},
#   {'start': 34.4, 'end': 35.5},
#   {'start': 41.8, 'end': 43.4},
#   {'start': 44.4, 'end': 45.6},
#   {'start': 46.9, 'end': 48.7},
#   {'start': 49.4, 'end': 50.5},
#   {'start': 51.3, 'end': 52.1},
#   {'start': 52.4, 'end': 54.3},
#   {'start': 54.9, 'end': 55.5},
#   {'start': 58.3, 'end': 59.5},
#   {'start': 60.9, 'end': 61.5},
#   {'start': 62.0, 'end': 62.4},
#   {'start': 65.6, 'end': 67.0},
#   {'start': 67.7, 'end': 68.1}],
#  'savhaw1/XC117953.ogg': [{'start': 5.4, 'end': 6.5},
#   {'start': 7.6, 'end': 9.1},
#   {'start': 10.2, 'end': 12.4},
#   {'start': 16.1, 'end': 16.8},
#   {'start': 72.1, 'end': 74.8},
#   {'start': 75.8, 'end': 76.5},
#   {'start': 76.9, 'end': 79.0},
#   {'start': 93.6, 'end': 94.8},
#   {'start': 97.8, 'end': 98.7},
#   {'start': 100.8, 'end': 101.7},
#   {'start': 103.2, 'end': 105.4},
#   {'start': 106.4, 'end': 107.5},
#   {'start': 109.2, 'end': 111.3},
#   {'start': 112.3, 'end': 114.8},
#   {'start': 116.0, 'end': 117.1},
#   {'start': 188.7, 'end': 190.0}],
#  'savhaw1/XC778000.ogg': [{'start': 3.3, 'end': 3.6}],
#  'secfly1/XC148044.ogg': [{'start': 32.5, 'end': 33.9},
#   {'start': 34.3, 'end': 35.5},
#   {'start': 41.0, 'end': 41.6}],
#  'secfly1/XC177854.ogg': [{'start': 45.7, 'end': 49.4}],
#  'secfly1/XC713731.ogg': [{'start': 11.7, 'end': 12.1}],
#  'secfly1/XC822540.ogg': [{'start': 0.3, 'end': 2.1}],
#  'shghum1/XC355659.ogg': [{'start': 1.5, 'end': 1.8},
#   {'start': 2.4, 'end': 2.8},
#   {'start': 3.0, 'end': 5.1}],
#  'shtfly1/XC532714.ogg': [{'start': 22.5, 'end': 24.4}],
#  'shtfly1/XC532721.ogg': [{'start': 16.3, 'end': 18.4}],
#  'smbani/XC148219.ogg': [{'start': 28.8, 'end': 29.6},
#   {'start': 30.2, 'end': 31.8},
#   {'start': 32.0, 'end': 32.8},
#   {'start': 36.5, 'end': 37.4},
#   {'start': 38.0, 'end': 38.8}],
#  'smbani/XC148250.ogg': [{'start': 32.5, 'end': 33.6},
#   {'start': 33.8, 'end': 34.8}],
#  'smbani/XC148298.ogg': [{'start': 28.4, 'end': 30.1},
#   {'start': 34.8, 'end': 35.9}],
#  'smbani/XC152241.ogg': [{'start': 9.5, 'end': 9.9}],
#  'smbani/XC196528.ogg': [{'start': 7.1, 'end': 7.9}],
#  'smbani/XC517920.ogg': [{'start': 39.2, 'end': 39.6},
#   {'start': 39.8, 'end': 41.4}],
#  'smbani/XC517921.ogg': [{'start': 56.7, 'end': 57.1},
#   {'start': 58.8, 'end': 59.9},
#   {'start': 63.6, 'end': 64.6},
#   {'start': 65.1, 'end': 66.1},
#   {'start': 69.4, 'end': 70.6},
#   {'start': 71.0, 'end': 72.3},
#   {'start': 74.9, 'end': 76.8},
#   {'start': 78.7, 'end': 79.0},
#   {'start': 79.5, 'end': 80.0},
#   {'start': 80.1, 'end': 81.1},
#   {'start': 82.0, 'end': 83.7},
#   {'start': 84.3, 'end': 85.6},
#   {'start': 93.9, 'end': 97.2}],
#  'smbani/XC523847.ogg': [{'start': 21.2, 'end': 23.7}],
#  'smbani/XC523852.ogg': [{'start': 25.8, 'end': 28.2}],
#  'smbani/XC532797.ogg': [{'start': 8.6, 'end': 11.054}],
#  'smbani/XC820345.ogg': [{'start': 16.7, 'end': 20.2},
#   {'start': 21.4, 'end': 22.2}],
#  'snoegr/XC559898.ogg': [{'start': 2.2, 'end': 3.6},
#   {'start': 4.0, 'end': 4.9}],
#  'snoegr/XC941118.ogg': [{'start': 1.1, 'end': 1.5},
#   {'start': 1.6, 'end': 1.9}],
#  'sobtyr1/XC121440.ogg': [{'start': 87.9, 'end': 92.7},
#   {'start': 93.8, 'end': 94.1},
#   {'start': 94.2, 'end': 94.9},
#   {'start': 95.4, 'end': 96.6},
#   {'start': 96.9, 'end': 98.0},
#   {'start': 100.0, 'end': 101.0},
#   {'start': 101.2, 'end': 102.6},
#   {'start': 104.6, 'end': 105.2},
#   {'start': 105.3, 'end': 105.8}],
#  'sobtyr1/XC148187.ogg': [{'start': 15.5, 'end': 16.1},
#   {'start': 16.2, 'end': 16.9},
#   {'start': 19.9, 'end': 22.2}],
#  'sobtyr1/XC148254.ogg': [{'start': 21.5, 'end': 22.0},
#   {'start': 22.3, 'end': 22.7},
#   {'start': 22.8, 'end': 23.7},
#   {'start': 26.7, 'end': 28.0},
#   {'start': 28.4, 'end': 29.1}],
#  'sobtyr1/XC148343.ogg': [{'start': 38.9, 'end': 39.5},
#   {'start': 39.6, 'end': 40.0},
#   {'start': 40.1, 'end': 40.5},
#   {'start': 41.0, 'end': 41.8},
#   {'start': 44.0, 'end': 44.8},
#   {'start': 45.1, 'end': 46.3}],
#  'sobtyr1/XC213747.ogg': [{'start': 46.3, 'end': 47.0},
#   {'start': 54.3, 'end': 55.1},
#   {'start': 56.7, 'end': 58.1}],
#  'sobtyr1/XC244923.ogg': [{'start': 227.5, 'end': 228.3},
#   {'start': 228.9, 'end': 229.5},
#   {'start': 229.8, 'end': 230.3},
#   {'start': 232.5, 'end': 233.4},
#   {'start': 235.0, 'end': 235.3},
#   {'start': 235.5, 'end': 237.0}],
#  'sobtyr1/XC307322.ogg': [{'start': 1.5, 'end': 2.2},
#   {'start': 5.6, 'end': 6.3}],
#  'sobtyr1/XC767451.ogg': [{'start': 2.6, 'end': 3.2}],
#  'sobtyr1/XC902101.ogg': [{'start': 1.9, 'end': 2.2},
#   {'start': 4.2, 'end': 4.5},
#   {'start': 5.2, 'end': 6.3},
#   {'start': 8.4, 'end': 9.0},
#   {'start': 37.2, 'end': 37.7},
#   {'start': 38.3, 'end': 39.3},
#   {'start': 40.1, 'end': 40.5},
#   {'start': 41.3, 'end': 41.9},
#   {'start': 43.1, 'end': 43.9}],
#  'sobtyr1/XC960834.ogg': [{'start': 32.9, 'end': 34.1},
#   {'start': 34.5, 'end': 35.6},
#   {'start': 36.8, 'end': 37.6},
#   {'start': 37.7, 'end': 38.2},
#   {'start': 39.6, 'end': 41.9},
#   {'start': 42.1, 'end': 43.4},
#   {'start': 43.8, 'end': 46.6}],
#  'sobtyr1/iNat380698.ogg': [{'start': 2.4, 'end': 2.8}],
#  'sobtyr1/iNat728246.ogg': [{'start': 0.5, 'end': 0.9}],
#  'sobtyr1/iNat880793.ogg': [{'start': 0.4, 'end': 0.9}],
#  'socfly1/XC148249.ogg': [{'start': 39.3, 'end': 41.8},
#   {'start': 45.4, 'end': 47.9}],
#  'socfly1/XC166807.ogg': [{'start': 1.3, 'end': 2.6}],
#  'socfly1/XC210856.ogg': [{'start': 0.9, 'end': 1.2}],
#  'socfly1/XC258993.ogg': [{'start': 0.7, 'end': 1.0}],
#  'socfly1/XC333936.ogg': [{'start': 1.9, 'end': 2.3}],
#  'socfly1/XC352974.ogg': [{'start': 2.6, 'end': 3.0}],
#  'socfly1/XC361771.ogg': [{'start': 120.6, 'end': 121.0},
#   {'start': 121.7, 'end': 124.2},
#   {'start': 125.1, 'end': 126.3},
#   {'start': 128.7, 'end': 129.8},
#   {'start': 130.2, 'end': 130.7},
#   {'start': 131.4, 'end': 132.9},
#   {'start': 133.4, 'end': 134.5},
#   {'start': 135.1, 'end': 135.7},
#   {'start': 135.9, 'end': 137.8},
#   {'start': 138.9, 'end': 139.5}],
#  'socfly1/XC520397.ogg': [{'start': 2.9, 'end': 3.8}],
#  'socfly1/XC523980.ogg': [{'start': 35.2, 'end': 36.8},
#   {'start': 39.1, 'end': 41.5}],
#  'socfly1/XC584783.ogg': [{'start': 3.6, 'end': 4.1}],
#  'socfly1/XC659531.ogg': [{'start': 10.6, 'end': 11.0}],
#  'socfly1/XC825528.ogg': [{'start': 161.3, 'end': 162.1}],
#  'socfly1/XC831163.ogg': [{'start': 1.6, 'end': 3.1},
#   {'start': 3.2, 'end': 4.1}],
#  'socfly1/XC927015.ogg': [{'start': 0.4, 'end': 0.7}],
#  'socfly1/XC960295.ogg': [{'start': 30.7, 'end': 31.9},
#   {'start': 32.1, 'end': 33.2},
#   {'start': 34.3, 'end': 37.6},
#   {'start': 38.1, 'end': 40.6}],
#  'socfly1/iNat135758.ogg': [{'start': 1.4, 'end': 1.7}],
#  'socfly1/iNat212090.ogg': [{'start': 1.0, 'end': 1.4}],
#  'socfly1/iNat363822.ogg': [{'start': 0.9, 'end': 1.2}],
#  'socfly1/iNat492939.ogg': [{'start': 0.9, 'end': 1.5}],
#  'socfly1/iNat546393.ogg': [{'start': 8.0, 'end': 8.4}],
#  'socfly1/iNat55224.ogg': [{'start': 7.2, 'end': 7.9},
#   {'start': 8.3, 'end': 8.7}],
#  'socfly1/iNat555188.ogg': [{'start': 2.2, 'end': 2.6}],
#  'socfly1/iNat582701.ogg': [{'start': 0.9, 'end': 1.9}],
#  'socfly1/iNat603326.ogg': [{'start': 6.6, 'end': 7.2},
#   {'start': 8.3, 'end': 9.1}],
#  'socfly1/iNat888220.ogg': [{'start': 35.0, 'end': 39.5},
#   {'start': 39.6, 'end': 42.5},
#   {'start': 43.0, 'end': 46.3},
#   {'start': 46.5, 'end': 47.0}],
#  'socfly1/iNat941156.ogg': [{'start': 0.5, 'end': 1.4},
#   {'start': 1.5, 'end': 2.5}],
#  'solsan/XC148200.ogg': [{'start': 69.3, 'end': 70.7},
#   {'start': 93.3, 'end': 94.0}],
#  'solsan/XC939487.ogg': [{'start': 1.7, 'end': 2.1}],
#  'solsan/iNat129203.ogg': [{'start': 8.9, 'end': 9.8}],
#  'soulap1/XC130484.ogg': [{'start': 50.1, 'end': 50.8}],
#  'soulap1/XC148064.ogg': [{'start': 28.1, 'end': 28.8},
#   {'start': 29.0, 'end': 29.4},
#   {'start': 33.2, 'end': 35.2}],
#  'soulap1/XC358450.ogg': [{'start': 10.4, 'end': 11.4},
#   {'start': 11.7, 'end': 12.8},
#   {'start': 13.2, 'end': 14.3},
#   {'start': 14.5, 'end': 16.4}],
#  'soulap1/XC384482.ogg': [{'start': 1.2, 'end': 1.5}],
#  'soulap1/XC385646.ogg': [{'start': 0.7, 'end': 1.1}],
#  'soulap1/XC524131.ogg': [{'start': 9.2, 'end': 9.6},
#   {'start': 35.6, 'end': 36.2},
#   {'start': 40.1, 'end': 42.7}],
#  'soulap1/XC534168.ogg': [{'start': 2.2, 'end': 2.7}],
#  'soulap1/XC620881.ogg': [{'start': 53.2, 'end': 53.6},
#   {'start': 53.8, 'end': 54.7}],
#  'soulap1/XC712956.ogg': [{'start': 4.8, 'end': 5.2}],
#  'soulap1/XC959661.ogg': [{'start': 43.7, 'end': 45.2},
#   {'start': 45.3, 'end': 46.6},
#   {'start': 47.6, 'end': 48.0},
#   {'start': 49.2, 'end': 50.7},
#   {'start': 51.3, 'end': 52.6}],
#  'soulap1/iNat1192016.ogg': [{'start': 1.3, 'end': 2.2}],
#  'soulap1/iNat311203.ogg': [{'start': 2.2, 'end': 2.8},
#   {'start': 6.4, 'end': 6.8}],
#  'soulap1/iNat376976.ogg': [{'start': 0.8, 'end': 8.2}],
#  'soulap1/iNat568455.ogg': [{'start': 3.8, 'end': 4.5},
#   {'start': 7.1, 'end': 7.7}],
#  'soulap1/iNat728225.ogg': [{'start': 6.3, 'end': 7.1}],
#  'spbwoo1/XC825522.ogg': [{'start': 71.2, 'end': 72.0},
#   {'start': 74.5, 'end': 77.1},
#   {'start': 78.2, 'end': 79.6},
#   {'start': 82.7, 'end': 83.1},
#   {'start': 83.2, 'end': 84.1}],
#  'spbwoo1/iNat1211842.ogg': [{'start': 0.0, 'end': 0.4},
#   {'start': 8.2, 'end': 8.6},
#   {'start': 15.9, 'end': 16.8}],
#  'speowl1/XC120560.ogg': [{'start': 1.5, 'end': 2.6},
#   {'start': 12.5, 'end': 13.2}],
#  'speowl1/XC134772.ogg': [{'start': 1.4, 'end': 4.3}],
#  'speowl1/XC146592.ogg': [{'start': 0.9, 'end': 2.1},
#   {'start': 6.5, 'end': 7.2}],
#  'speowl1/XC166045.ogg': [{'start': 0.6, 'end': 2.2},
#   {'start': 2.9, 'end': 4.2},
#   {'start': 5.8, 'end': 6.9},
#   {'start': 9.0, 'end': 9.7},
#   {'start': 11.0, 'end': 11.9},
#   {'start': 19.8, 'end': 20.4},
#   {'start': 29.7, 'end': 30.0}],
#  'speowl1/XC182714.ogg': [{'start': 1.6, 'end': 2.3}],
#  'speowl1/XC1955.ogg': [{'start': 2.9, 'end': 5.4},
#   {'start': 68.7, 'end': 69.5}],
#  'speowl1/XC214127.ogg': [{'start': 2.6, 'end': 3.9}],
#  'speowl1/XC238947.ogg': [{'start': 1.4, 'end': 2.8},
#   {'start': 8.8, 'end': 9.7},
#   {'start': 15.2, 'end': 15.8},
#   {'start': 22.5, 'end': 23.3}],
#  'speowl1/XC238948.ogg': [{'start': 0.5, 'end': 2.3}],
#  'speowl1/XC246571.ogg': [{'start': 53.0, 'end': 53.7},
#   {'start': 53.8, 'end': 55.2},
#   {'start': 55.3, 'end': 55.7},
#   {'start': 56.6, 'end': 57.6},
#   {'start': 57.7, 'end': 59.4},
#   {'start': 59.8, 'end': 60.3},
#   {'start': 61.5, 'end': 62.6},
#   {'start': 63.3, 'end': 64.5},
#   {'start': 66.0, 'end': 66.4},
#   {'start': 66.9, 'end': 67.3},
#   {'start': 67.4, 'end': 68.1},
#   {'start': 69.0, 'end': 70.5}],
#  'speowl1/XC257746.ogg': [{'start': 3.3, 'end': 4.2}],
#  'speowl1/XC261642.ogg': [{'start': 2.1, 'end': 2.4}],
#  'speowl1/XC28499.ogg': [{'start': 1.9, 'end': 3.9}],
#  'speowl1/XC326566.ogg': [{'start': 1.3, 'end': 2.0},
#   {'start': 3.2, 'end': 4.1}],
#  'speowl1/XC362947.ogg': [{'start': 5.3, 'end': 6.8},
#   {'start': 7.6, 'end': 8.4}],
#  'speowl1/XC376994.ogg': [{'start': 1.3, 'end': 1.7}],
#  'speowl1/XC379128.ogg': [{'start': 3.1, 'end': 3.6}],
#  'speowl1/XC383307.ogg': [{'start': 2.2, 'end': 3.0}],
#  'speowl1/XC386692.ogg': [{'start': 2.1, 'end': 3.4}],
#  'speowl1/XC391439.ogg': [{'start': 0.9, 'end': 2.4},
#   {'start': 3.0, 'end': 5.9},
#   {'start': 15.3, 'end': 15.7},
#   {'start': 16.9, 'end': 18.9}],
#  'speowl1/XC401391.ogg': [{'start': 1.1, 'end': 1.9}],
#  'speowl1/XC415475.ogg': [{'start': 56.4, 'end': 56.8}],
#  'speowl1/XC421495.ogg': [{'start': 3.6, 'end': 4.5}],
#  'speowl1/XC453618.ogg': [{'start': 7.2, 'end': 7.5},
#   {'start': 9.7, 'end': 10.7}],
#  'speowl1/XC457585.ogg': [{'start': 2.2, 'end': 3.4},
#   {'start': 13.0, 'end': 13.4},
#   {'start': 13.6, 'end': 14.0},
#   {'start': 27.5, 'end': 28.0}],
#  'speowl1/XC471143.ogg': [{'start': 1.2, 'end': 1.7},
#   {'start': 2.1, 'end': 3.4},
#   {'start': 3.9, 'end': 5.0}],
#  'speowl1/XC48749.ogg': [{'start': 3.5, 'end': 5.1}],
#  'speowl1/XC489383.ogg': [{'start': 1.4, 'end': 3.9},
#   {'start': 12.5, 'end': 12.9},
#   {'start': 19.1, 'end': 19.9},
#   {'start': 20.4, 'end': 23.1},
#   {'start': 33.6, 'end': 34.4}],
#  'speowl1/XC490111.ogg': [{'start': 1.8, 'end': 3.5}],
#  'speowl1/XC491707.ogg': [{'start': 1.4, 'end': 2.1}],
#  'speowl1/XC510970.ogg': [{'start': 1.6, 'end': 3.7}],
#  'speowl1/XC51625.ogg': [{'start': 1.9, 'end': 3.3}],
#  'speowl1/XC525218.ogg': [{'start': 261.1, 'end': 261.5}],
#  'speowl1/XC525921.ogg': [{'start': 3.7, 'end': 4.1}],
#  'speowl1/XC529813.ogg': [{'start': 3.0, 'end': 4.1},
#   {'start': 22.7, 'end': 23.1},
#   {'start': 36.4, 'end': 36.7}],
#  ...}
